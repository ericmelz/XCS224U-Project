# %% [markdown]
# # Index Receipts

# %%
from ir import IndexDataframe, search_loop, make_dictionary, make_raw_to_web, \
SimpleQueryMaker, WildQueryMaker, MashedWildQueryMaker, FuzzyMashedWildQueryMaker, \
NgramWildQueryMaker, XorNgramWildQueryMaker, BoostedNgramWildQueryMaker, FuzzyNgramWildQueryMaker, \
Config, SimpleSearcher, evaluate
import pandas as pd
from datetime import datetime
from org.apache.lucene.analysis.standard import StandardAnalyzer

# %%
INDEX_DIR = "indexes/receipts1"

# %%
path = '../data/raw_web_joined/703_00198_2020-03-20_3_1391204_joined.json'
df = pd.read_json(path)

# %%
def index_test(quiet=False):
    start = datetime.now()
    try:
        IndexDataframe(df, INDEX_DIR, StandardAnalyzer(), quiet)
        end = datetime.now()
        print('Elapsed: %s' % (end - start))
    except Exception as e:
        print("Failed: %s" % e)
        raise e

# %%
index_test(True)
# Out:
# .done
# Elapsed: 0:00:00.215915

# %%
#search_loop(INDEX_DIR, 'web', explain=True)

# %% [markdown]
# ## Equivalency Evaluation
# ```
# build a table of raw -> [web]
# where [web] is all the possible values of matches for raw
# example: 'FFST CAT FOOD' -> ['Fancy Feast Flaked Fish Cat Food', 'Purina Fancy Feast Chicken Cat Food']
#
# search on query (e.g. FFST CAT FOOD) if top result is any of the ones associated with query, it counts as a hit
# ```

# %% [markdown]
# ## Wildcard Technique
# ```
# when building a query evaluate against dictionary of seen web terms
# unseen tokens get wildcard treatment
# wildcard treatment means insert * between each letter
# e.g., FFST CAT FOOD -> F*F*S*T CAT FOOD
# since cat and food exist in dictionary
# ```

# %%
WORDS = make_dictionary(df)

# %%
RAW_TO_WEB = make_raw_to_web(df)

# %% [markdown]
# ## Scoring
# ### Interface
# ```
# def is_hit(raw, config): -> bool
#
# config:
#   Index
#   Searcher
#   QueryMaker
# ```
#
# Algorithm:
# We lookup the webs for the webs for the raw to generate the hit candidates
# we process raw into a query using QueryMaker
# We run the query using Searcher
# Index may not be necessary
# If the top result is in webs, we return true, otherwise false

# %%
qm = SimpleQueryMaker()

# %%
ss = SimpleSearcher(INDEX_DIR)

# %%
simple_config = Config(qm, ss)

# %%
queries = ['AVOCADO', 'FFST CAT FOOD']

# %%
evaluate(queries, simple_config, RAW_TO_WEB)
# Out:
# (0.5, ['AVOCADO'])

# %%
queries = df.raw.unique()

# %%
simple_score, simple_misses = evaluate(queries, simple_config, RAW_TO_WEB)

# %%
len(queries)
# Out:
# 69

# %%
wqm = WildQueryMaker(WORDS)

# %%
wild_config = Config(wqm, ss)

# %%
wild_score, wild_misses = evaluate(queries, wild_config, RAW_TO_WEB)

# %%
simple_score
# Out:
# 0.6231884057971014

# %%
wild_score
# Out:
# 0.8405797101449275

# %%
simple_misses
# Out:
# ['KRO WATER',
#  'CA REDEM VAL',
#  'ARTICHOKES',
#  'BYND SSG HT ITLN',
#  'BRHD CHEESE',
#  'CUCUMBERS',
#  'FRGO STR CHS',
#  'GLBNI STR CHS',
#  'KRO SOAP',
#  'KRO CCNT MK',
#  'MSHRM BYBL WHL',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'ASP ORG',
#  'PPRS BL GRN ORGN',
#  'RADISH ORG',
#  'SQSH YLW ORG',
#  'TOMATO ORGNC',
#  'PRSL MPL TKY GNG',
#  'PRSL MUENSTR',
#  'STO CRT BABY ORGNC',
#  'STO CCNT MILK',
#  'STO BROTH',
#  'STO CARROTS ORGNC',
#  'STN CHCK RST',
#  'SFTSOAP KTCHN FRSH']

# %% [markdown]
# ### wild_misses
# `wild_misses` is the set of queries that wasn't matched by using wild queries on terms.
# Examples
# * `CA REDEM VAL` - difficult to match since little lexical overlap
# * `ARTICHOKES`, `CUCMBER` - plural mismatmatch
# * `BRHD *` `PRSL *`, `STO *`   - Wildcard won't match terms because BRHD, PRSL, STO spans multiple terms.  However, a wildcard match against the entire web string might work ok
# * `KRO SOAP` - Matched `Kroger® Pear & Coconut Hand Soap` which had associated raw field of `KRO PEAR COCONUT`.  The actual hit was at rank 2.  Measuring precision@2 would have caught it.
# * `LES PET CHEESE BAR` - Matched `Les Petites Havarati Cheese Wedge`.  The second hit was correct, with web value of `Les Petites Kosher Colby Jack Cheese`.  Note that neither web had disambiguating `BAR` term present.
# * `BROWN ONIONS` - Matched `Onions - Green`.  Correct hit was ranked second: `Onions - Yellow`.  Note that there was no Yellow Onions in the web texts.

# %%
wild_misses
# Out:
# ['CA REDEM VAL',
#  'ARTICHOKES',
#  'BRHD CHEESE',
#  'CUCUMBERS',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'PRSL MUENSTR',
#  'STO CCNT MILK',
#  'STO BROTH',
#  'STO CARROTS ORGNC']

# %% [markdown]
# ### wild_eliminees
# `wild_eliminees` is the set of simple_misses that were eliminated by using wildcard queries on terms
# Example: `ASP ORG` is eliminated by wildcard queries, probably due to match of `Asparagus` and `Organic`

# %%
wild_eliminees = set(simple_misses) - set(wild_misses)
wild_eliminees
# Out:
# {'ASP ORG',
#  'BYND SSG HT ITLN',
#  'FRGO STR CHS',
#  'GLBNI STR CHS',
#  'KRO CCNT MK',
#  'KRO WATER',
#  'MSHRM BYBL WHL',
#  'PPRS BL GRN ORGN',
#  'PRSL MPL TKY GNG',
#  'RADISH ORG',
#  'SFTSOAP KTCHN FRSH',
#  'SQSH YLW ORG',
#  'STN CHCK RST',
#  'STO CRT BABY ORGNC',
#  'TOMATO ORGNC'}

# %%
"""
Note that there are no `wild_misses` that were not in `simple_misses`.
This means that using wildcards doesn't hurt performance
"""
set(wild_misses) - set(simple_misses)
# Out:
# set()

# %% [markdown]
# ## TODO
# * Try not not analyzing the entire web string and doing wildcard matches against only the unanalyzed string (don't do wildcard matches against terms
# * Try wildcard matching against terms and entire unanalyzed web string

# %% [markdown]
# ### Fuzzy match
# Notice that wildcard can over match, resulting in false positives
# For example `m*ue*en*s*t*r` matches `MoisturePartSkimOriginalMozzarellaStringCheese`
# See the next example
# Combining the wildcard match with a fuzzy match makes Muenster surface to the top (see following examples)

# %%
ss.search('mashed_web:m*u*e*n*s*t*r*')[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:FRGO STR CHS> stored,indexed,tokenized<web:Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese> stored,indexed,tokenized<mashed_web:frigocheeseheadslowmoisturepartskimoriginalmozzarellastringcheese cheeseheadslowmoisturepartskimoriginalmozzarellastringcheese headslowmoisturepartskimoriginalmozzarellastringcheese lowmoisturepartskimoriginalmozzarellastringcheese moisturepartskimoriginalmozzarellastringcheese partskimoriginalmozzarellastringcheese skimoriginalmozzarellastringcheese originalmozzarellastringcheese mozzarellastringcheese stringcheese cheese> stored,indexed,tokenized<unigrams:frigo cheese heads low moisture part skim original mozzarella string cheese> stored,indexed,tokenized<bigrams:mozzarella_string string_cheese> stored,indexed,tokenized<trigrams:mozzarella_string_cheese> stored,indexed,tokenized<ngrams:frigo cheese heads low moisture part skim original mozzarella string cheese mozzarella_string string_cheese mozzarella_string_cheese> stored<id:4171623216>>>

# %%
ss.explain('mashed_web:m*u*e*n*s*t*r*')
# Out:
# mashed_web:m*u*e*n*s*t*r*
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 1.0
# 1.0 = mashed_web:m*u*e*n*s*t*r*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 1.0
# 1.0 = mashed_web:m*u*e*n*s*t*r*
#
# ------------

# %%
ss.search('mashed_web:m*u*e*n*s*t*r*  meunstr~')[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:PRSL MUENSTR> stored,indexed,tokenized<web:Private Selection™ Grab & Go Muenster Cheese> stored,indexed,tokenized<mashed_web:privateselectiongrabgomuenstercheese selectiongrabgomuenstercheese grabgomuenstercheese gomuenstercheese gomuenstercheese muenstercheese cheese> stored,indexed,tokenized<unigrams:private selection grab  go muenster cheese> stored,indexed,tokenized<bigrams:private_selection selection_grab go_muenster muenster_cheese> stored,indexed,tokenized<trigrams:private_selection_grab go_muenster_cheese> stored,indexed,tokenized<ngrams:private selection grab  go muenster cheese private_selection selection_grab go_muenster muenster_cheese private_selection_grab go_muenster_cheese> stored<id:20615390000>>>

# %%
ss.explain('mashed_web:m*u*e*n*s*t*r*  meunstr~')
# Out:
# mashed_web:m*u*e*n*s*t*r*  meunstr~
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.2037241458892822
# 2.2037241 = sum of:
#   1.0 = mashed_web:m*u*e*n*s*t*r*
#   1.2037241 = weight(web:muenster in 59) [BM25Similarity], result of:
#     1.2037241 = score(freq=1.0), product of:
#       0.71428573 = boost
#       4.037186 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         1 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:m*u*e*n*s*t*r*
#
# ------------

# %%
ss.search('mashed_web:p*r*s*l* prsl~ mashed_web:m*u*e*n*s*t*r*  meunstr~')[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:PRSL MUENSTR> stored,indexed,tokenized<web:Private Selection™ Grab & Go Muenster Cheese> stored,indexed,tokenized<mashed_web:privateselectiongrabgomuenstercheese selectiongrabgomuenstercheese grabgomuenstercheese gomuenstercheese gomuenstercheese muenstercheese cheese> stored,indexed,tokenized<unigrams:private selection grab  go muenster cheese> stored,indexed,tokenized<bigrams:private_selection selection_grab go_muenster muenster_cheese> stored,indexed,tokenized<trigrams:private_selection_grab go_muenster_cheese> stored,indexed,tokenized<ngrams:private selection grab  go muenster cheese private_selection selection_grab go_muenster muenster_cheese private_selection_grab go_muenster_cheese> stored<id:20615390000>>>

# %%
ss.explain('mashed_web:p*r*s*l* prsl~ mashed_web:m*u*e*n*s*t*r*  meunstr~')
# Out:
# mashed_web:p*r*s*l* prsl~ mashed_web:m*u*e*n*s*t*r*  meunstr~
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 3.2037241458892822
# 3.2037241 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#   1.0 = mashed_web:m*u*e*n*s*t*r*
#   1.2037241 = weight(web:muenster in 59) [BM25Similarity], result of:
#     1.2037241 = score(freq=1.0), product of:
#       0.71428573 = boost
#       4.037186 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         1 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#   1.0 = mashed_web:m*u*e*n*s*t*r*
#
# ------------
# Earthwise Palm Trees Reusable Shopping Bag | PALM SHOPPING BAGS | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Organic - Parsley - Curly | PARSLEY ORG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Organic Italian Parsley | PARSLEY ORG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Private Selection™ Campari Tomatoes | TOMATOES CAMPARI | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Classic Pate Savory Salmon Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Classic Pate Tender Beef Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 0.4968179762363434
# 0.49681798 = sum of:
#   0.49681798 = weight(web:pre in 13) [BM25Similarity], result of:
#     0.49681798 = score(freq=1.0), product of:
#       0.3333333 = boost
#       4.037186 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         1 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------

# %% [markdown]
# ## Mashed and Fuzzy
# * mashed wildcard (matching mashed_web field with wildcard query)
# * fuzzy mashed wildcard (mix in fuzzy terms to mashed wildcard)

# %%
mwqm = MashedWildQueryMaker(WORDS)

# %%
mashed_wild_config = Config(mwqm, ss)

# %%
mashed_wild_score, mashed_wild_misses = evaluate(queries, mashed_wild_config, RAW_TO_WEB)

# %%
mashed_wild_score
# Out:
# 0.8840579710144928

# %%
mashed_wild_misses
# Out:
# ['CA REDEM VAL',
#  'ARTICHOKES',
#  'CUCUMBERS',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'PRSL MUENSTR',
#  'STO CARROTS ORGNC']

# %% [markdown]
# ### mashed_wild_eliminees
# `mashed_wild_eliminees` is the set of `wild_misses` that were eliminated by using mashed wildcard queries on terms
# Example: `BRHD` is eliminated by wildcard queries, probably due to match of `BRHD` and `Boar's Head`

# %%
mashed_wild_eliminees = set(wild_misses) - set(mashed_wild_misses)
mashed_wild_eliminees
# Out:
# {'BRHD CHEESE', 'STO BROTH', 'STO CCNT MILK'}

# %%
regressions = set(mashed_wild_misses) - set(wild_misses)
regressions
# Out:
# set()

# %%
fmwqm = FuzzyMashedWildQueryMaker(WORDS)

# %%
fuzzy_mashed_wild_config = Config(fmwqm, ss)

# %%
fuzzy_mashed_wild_score, fuzzy_mashed_wild_misses = evaluate(queries, fuzzy_mashed_wild_config, RAW_TO_WEB)

# %%
fuzzy_mashed_wild_score
# Out:
# 0.8985507246376812

# %%
fuzzy_mashed_wild_misses
# Out:
# ['CA REDEM VAL',
#  'FRGO STR CHS',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'OCEANS HALO BROTH',
#  'BROWN ONIONS',
#  'STO CARROTS ORGNC']

# %% [markdown]
# ### fuzzy_mashed_wild_eliminees
# By introducing fuzzy matching, we get plurals (`ARTICHOKES`, `CUCUMBERS`) in addition to Mild misspellings (`MUENSTR`).

# %%
fuzzy_mashed_wild_eliminees = set(mashed_wild_misses) - set(fuzzy_mashed_wild_misses)
fuzzy_mashed_wild_eliminees
# Out:
# {'ARTICHOKES', 'CUCUMBERS', 'PRSL MUENSTR'}

# %%
fuzzy_mashed_regressions = set(fuzzy_mashed_wild_misses) - set(mashed_wild_misses)
fuzzy_mashed_regressions
# Out:
# {'FRGO STR CHS', 'OCEANS HALO BROTH'}

# %%
ss.search(fmwqm.make_query('FRGO STR CHS'))[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:BEEF STR FRY> stored,indexed,tokenized<web:Beef Choice For Stir Fry> stored,indexed,tokenized<mashed_web:beefchoiceforstirfry choiceforstirfry forstirfry stirfry fry> stored,indexed,tokenized<unigrams:beef choice for stir fry> stored,indexed,tokenized<bigrams:> stored,indexed,tokenized<trigrams:> stored,indexed,tokenized<ngrams:beef choice for stir fry  > stored<id:20254600000>>>

# %% [markdown]
# FRGO STR CHS matches Beef Choice For Stir Fry
# * frgo~ matches fry  i think???
# * frgo~ matches for i think???
# * str~ matches stir
# * c*h*s* matches choice for stir.  This would be eliminated if we only consider using bigram/trigram terms (choice for stir hopefully isn't a trigram)
#
# This indicates that we should eliminate web words that are shorter than raw words- both for and fry are shorter than frgo~
#
# The False Negative is the second hit
# * Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese
# * frgo~ matches Frigo
# * chs~ does not match Cheese... why?
# * str~ does not match String... why?
#
# I think maybe bonus points should be awarded for prefix matches
# Examples:
# KRO => Kroger
# STR => String
#
# This could be accomplished by adding prefix queries
# e.g., in addition to S*T*R*, have STR*

# %%
ss.explain(fmwqm.make_query('FRGO STR CHS'))
# Out:
# mashed_web:f*r*g*o* frgo~ mashed_web:s*t*r* str~ mashed_web:c*h*s* chs~
# Beef Choice For Stir Fry | BEEF STR FRY | 3.921565532684326
# 3.9215655 = sum of:
#   0.5105596 = weight(web:fry in 10) [BM25Similarity], result of:
#     0.5105596 = score(freq=1.0), product of:
#       0.3333333 = boost
#       3.1898882 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         3 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = mashed_web:s*t*r*
#   0.47033533 = weight(web:for in 10) [BM25Similarity], result of:
#     0.47033533 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   0.94067067 = weight(web:stir in 10) [BM25Similarity], result of:
#     0.94067067 = score(freq=1.0), product of:
#       0.6666666 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 3.7917346954345703
# 3.7917347 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   0.7917348 = weight(web:frigo in 24) [BM25Similarity], result of:
#     0.7917348 = score(freq=1.0), product of:
#       0.75 = boost
#       3.1898882 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         3 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 3.4184412956237793
# 3.4184413 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#   0.20922069 = weight(web:can in 64) [BM25Similarity], result of:
#     0.20922069 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.2864259 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         14.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   0.20922069 = weight(web:cat in 64) [BM25Similarity], result of:
#     0.20922069 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.2864259 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         14.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 2.8252804279327393
# 2.8252804 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   0.8252804 = weight(web:free in 70) [BM25Similarity], result of:
#     0.8252804 = score(freq=2.0), product of:
#       0.5 = boost
#       3.1898882 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         3 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.5174353 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         2.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         10.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 2.4088759422302246
# 2.408876 = sum of:
#   1.0 = mashed_web:s*t*r*
#   0.40887594 = weight(web:sea in 74) [BM25Similarity], result of:
#     0.40887594 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Galbani String Cheese | GLBNI STR CHS | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Kroger® Honey Citrus & Shea Butter Hand Soap Bottle | KRO SOAP | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   0.0 = ConstantScore(web:go)^0.0
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Simple Truth™ Natural Angus Beef Chuck Roast | STN CHCK RST | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Softsoap Kitchen Fresh Hands Citrus Extracts Antibacterial Hand Soap | SFTSOAP KTCHN FRSH | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Taylor Farms Roasted Garlic Chopped Salad Kit | TYFR SALAD KIT | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 1.624935507774353
# 1.6249355 = sum of:
#   0.6249355 = weight(web:free in 69) [BM25Similarity], result of:
#     0.6249355 = score(freq=1.0), product of:
#       0.5 = boost
#       3.1898882 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         3 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.39182281 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         8.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Fancy Feast Classic Pate Cod Sole & Shrimp Feast Wet Cat Food | FFST CAT FOOD | 1.4834654331207275
# 1.4834654 = sum of:
#   1.0 = mashed_web:c*h*s*
#   0.24173269 = weight(web:cat in 21) [BM25Similarity], result of:
#     0.24173269 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   0.24173269 = weight(web:cod in 21) [BM25Similarity], result of:
#     0.24173269 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.4834654331207275
# 1.4834654 = sum of:
#   1.0 = mashed_web:c*h*s*
#   0.24173269 = weight(web:can in 60) [BM25Similarity], result of:
#     0.24173269 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   0.24173269 = weight(web:cat in 60) [BM25Similarity], result of:
#     0.24173269 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.43745756149292
# 1.4374576 = sum of:
#   1.0 = mashed_web:s*t*r*
#   0.43745756 = weight(web:qty in 2) [BM25Similarity], result of:
#     0.43745756 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 1.3507394790649414
# 1.3507395 = sum of:
#   1.0 = mashed_web:c*h*s*
#   0.35073948 = weight(web:les in 34) [BM25Similarity], result of:
#     0.35073948 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 1.3262217044830322
# 1.3262217 = sum of:
#   1.0 = mashed_web:c*h*s*
#   0.32622176 = weight(web:les in 35) [BM25Similarity], result of:
#     0.32622176 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 1.3241591453552246
# 1.3241591 = sum of:
#   1.0 = mashed_web:s*t*r*
#   0.3241592 = weight(web:qty in 3) [BM25Similarity], result of:
#     0.3241592 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 1.2417327165603638
# 1.2417327 = sum of:
#   1.0 = mashed_web:c*h*s*
#   0.24173269 = weight(web:cat in 22) [BM25Similarity], result of:
#     0.24173269 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Cholula Original Hot Sauce | CHOLULA HOT SAUCE | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Kroger® Pear & Coconut Hand Soap | KRO PEAR COCONUT | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Private Selection™ Campari Tomatoes | TOMATOES CAMPARI | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   0.0 = ConstantScore(web:go)^0.0
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth™ Pecan Halves | ST PECAN HLV RAW | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Smart Chicken Organic Ground Chicken 95% Lean | MBA CHK GROUND | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Softsoap Fresh Breeze Liquid Hand Soap | SFTSOAP KTCHN FRSH | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Taylor Farms Avocado Ranch Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Nut Pods Hazelnut Unsweetened Dairy-Free Creamer | NUTPODS CREAMER | 0.6657661199569702
# 0.6657661 = sum of:
#   0.6657661 = weight(web:free in 41) [BM25Similarity], result of:
#     0.6657661 = score(freq=1.0), product of:
#       0.5 = boost
#       3.1898882 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         3 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Purina Fancy Feast Classic Pate Savory Salmon Feast Wet Cat Food Can | FFST CAT FOOD | 0.4596558213233948
# 0.45965582 = sum of:
#   0.22982791 = weight(web:can in 61) [BM25Similarity], result of:
#     0.22982791 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.31463745 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         12.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   0.22982791 = weight(web:cat in 61) [BM25Similarity], result of:
#     0.22982791 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.31463745 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         12.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Purina Fancy Feast Classic Pate Tender Beef Feast Wet Cat Food Can | FFST CAT FOOD | 0.4596558213233948
# 0.45965582 = sum of:
#   0.22982791 = weight(web:can in 62) [BM25Similarity], result of:
#     0.22982791 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.31463745 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         12.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   0.22982791 = weight(web:cat in 62) [BM25Similarity], result of:
#     0.22982791 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.31463745 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         12.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Purina Fancy Feast Minced Turkey Feast in Sauce Wet Cat Food Can | FFST CAT FOOD | 0.4596558213233948
# 0.45965582 = sum of:
#   0.22982791 = weight(web:can in 63) [BM25Similarity], result of:
#     0.22982791 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.31463745 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         12.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   0.22982791 = weight(web:cat in 63) [BM25Similarity], result of:
#     0.22982791 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.31463745 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         12.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) Essentia Ionized Alkaline Water | ESNT WATER | 0.4374575614929199
# 0.43745756 = sum of:
#   0.43745756 = weight(web:qty in 0) [BM25Similarity], result of:
#     0.43745756 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) FIJI Natural Artesian Water | FIJI WATER | 0.4374575614929199
# 0.43745756 = sum of:
#   0.43745756 = weight(web:qty in 1) [BM25Similarity], result of:
#     0.43745756 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Atkins Endulge Chocolate Coconut Treat Bar | ATKINS BARS | 0.4374575614929199
# 0.43745756 = sum of:
#   0.43745756 = weight(web:bar in 8) [BM25Similarity], result of:
#     0.43745756 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# $000.10 CRV DEPOSIT | CA REDEM VAL | 0.4127867817878723
# 0.41278678 = sum of:
#   0.41278678 = weight(web:crv in 4) [BM25Similarity], result of:
#     0.41278678 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# $000.10 CRV DEPOSIT | CA REDEM VAL | 0.4127867817878723
# 0.41278678 = sum of:
#   0.41278678 = weight(web:crv in 5) [BM25Similarity], result of:
#     0.41278678 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Tomatoes - On the Vine | TOMATO ORGNC | 0.3507394790649414
# 0.35073948 = sum of:
#   0.35073948 = weight(web:the in 52) [BM25Similarity], result of:
#     0.35073948 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# ABOUND™ Natural Clumping Cat Litter | ABOUND CAT LITTER | 0.326221764087677
# 0.32622176 = sum of:
#   0.32622176 = weight(web:cat in 6) [BM25Similarity], result of:
#     0.32622176 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Kroger® Romaine Leaf Single Cut Leaf | KRO ROMAINE | 0.30490782856941223
# 0.30490783 = sum of:
#   0.30490783 = weight(web:cut in 31) [BM25Similarity], result of:
#     0.30490783 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Beyond Meat The Beyond Burger Plant-Based Burger Patties | BYND BURGER | 0.26966971158981323
# 0.2696697 = sum of:
#   0.2696697 = weight(web:the in 12) [BM25Similarity], result of:
#     0.2696697 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Fancy Feast Flaked Fish & Shrimp Feast Wet Cat Food | FFST CAT FOOD | 0.26966971158981323
# 0.2696697 = sum of:
#   0.2696697 = weight(web:cat in 23) [BM25Similarity], result of:
#     0.2696697 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.1913595 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         9 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# MEAT FS | MEAT FS | 0.0
# 0.0 = sum of:
#   0.0 = ConstantScore(web:fs)^0.0
#
# ------------
# MEAT FS | MEAT FS | 0.0
# 0.0 = sum of:
#   0.0 = ConstantScore(web:fs)^0.0
#
# ------------

# %% [markdown]
# Note above matches a stop word `(web:for)`
# Maybe eliminating stop words could help

# %%
ss.search(mwqm.make_query('FRGO STR CHS'))[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:FRGO STR CHS> stored,indexed,tokenized<web:Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese> stored,indexed,tokenized<mashed_web:frigocheeseheadslowmoisturepartskimoriginalmozzarellastringcheese cheeseheadslowmoisturepartskimoriginalmozzarellastringcheese headslowmoisturepartskimoriginalmozzarellastringcheese lowmoisturepartskimoriginalmozzarellastringcheese moisturepartskimoriginalmozzarellastringcheese partskimoriginalmozzarellastringcheese skimoriginalmozzarellastringcheese originalmozzarellastringcheese mozzarellastringcheese stringcheese cheese> stored,indexed,tokenized<unigrams:frigo cheese heads low moisture part skim original mozzarella string cheese> stored,indexed,tokenized<bigrams:mozzarella_string string_cheese> stored,indexed,tokenized<trigrams:mozzarella_string_cheese> stored,indexed,tokenized<ngrams:frigo cheese heads low moisture part skim original mozzarella string cheese mozzarella_string string_cheese mozzarella_string_cheese> stored<id:4171623216>>>

# %%
fmwqm.make_query('FRGO STR CHS')
# Out:
# 'mashed_web:f*r*g*o* frgo~ mashed_web:s*t*r* str~ mashed_web:c*h*s* chs~'

# %% [markdown]
# OCEANS HALO BROTH matches Pero Organic Green Beans
# * o*c*e*a*n*s* matches OrganiC green bEANS - this would have been eliminated using ngrams

# %%
ss.explain(fmwqm.make_query('OCEANS HALO BROTH'))
# Out:
# mashed_web:o*c*e*a*n*s* oceans~ mashed_web:h*a*l*o* halo~ broth
# Pero Organic Green Beans | GREEN BEANS ORGNC | 2.257633686065674
# 2.2576337 = sum of:
#   1.0 = mashed_web:o*c*e*a*n*s*
#   1.2576336 = weight(web:beans in 56) [BM25Similarity], result of:
#     1.2576336 = score(freq=1.0), product of:
#       0.6 = boost
#       4.037186 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         1 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.51918733 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         4.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# NO CHICKEN BROTH TETRA | OCEANS HALO BROTH | 1.8308416604995728
# 1.8308417 = sum of:
#   1.8308417 = weight(web:broth in 40) [BM25Similarity], result of:
#     1.8308417 = score(freq=1.0), product of:
#       3.5263605 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         2 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.51918733 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         4.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Softsoap Kitchen Fresh Hands Citrus Extracts Antibacterial Hand Soap | SFTSOAP KTCHN FRSH | 1.5424333810806274
# 1.5424334 = sum of:
#   1.0 = mashed_web:h*a*l*o*
#   0.5424334 = weight(web:hand in 77) [BM25Similarity], result of:
#     0.5424334 = score(freq=1.0), product of:
#       0.5 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 1.2307478189468384
# 1.2307478 = sum of:
#   1.2307478 = weight(web:broth in 70) [BM25Similarity], result of:
#     1.2307478 = score(freq=1.0), product of:
#       3.5263605 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         2 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.34901363 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         10.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:h*a*l*o*
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:h*a*l*o*
#
# ------------
# Mountain High Plain Original Whole Milk Yoghurt | MOUNTAIN HGH YOGRT | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:h*a*l*o*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:h*a*l*o*
#
# ------------
# Del Cabo Cucumber Og 16 Oz | CUCUMBERS | 0.6561863422393799
# 0.65618634 = sum of:
#   0.65618634 = weight(web:cabo in 19) [BM25Similarity], result of:
#     0.65618634 = score(freq=1.0), product of:
#       0.5 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Earthwise Palm Trees Reusable Shopping Bag | PALM SHOPPING BAGS | 0.6561863422393799
# 0.65618634 = sum of:
#   0.65618634 = weight(web:palm in 20) [BM25Similarity], result of:
#     0.65618634 = score(freq=1.0), product of:
#       0.5 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Kroger® Pear & Coconut Hand Soap | KRO PEAR COCONUT | 0.6561863422393799
# 0.65618634 = sum of:
#   0.65618634 = weight(web:hand in 29) [BM25Similarity], result of:
#     0.65618634 = score(freq=1.0), product of:
#       0.5 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Softsoap Fresh Breeze Liquid Hand Soap | SFTSOAP KTCHN FRSH | 0.6561863422393799
# 0.65618634 = sum of:
#   0.65618634 = weight(web:hand in 76) [BM25Similarity], result of:
#     0.65618634 = score(freq=1.0), product of:
#       0.5 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 0.6133139729499817
# 0.613314 = sum of:
#   0.613314 = weight(web:salt in 74) [BM25Similarity], result of:
#     0.613314 = score(freq=1.0), product of:
#       0.5 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Kroger® Honey Citrus & Shea Butter Hand Soap Bottle | KRO SOAP | 0.5424333810806274
# 0.5424334 = sum of:
#   0.5424334 = weight(web:hand in 27) [BM25Similarity], result of:
#     0.5424334 = score(freq=1.0), product of:
#       0.5 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------

# %% [markdown]
# ## ngrams
# Instead of matching wildcards on mashed_web field, match wildcards on web, bigrams, and trigrams

# %%
nwqm = NgramWildQueryMaker(WORDS)

# %%
nwqm.make_query('FRGO STR CHS')
# Out:
# 'web:f*r*g*o* bigrams:f*r*g*o* trigrams:f*r*g*o* web:s*t*r* bigrams:s*t*r* trigrams:s*t*r* web:c*h*s* bigrams:c*h*s* trigrams:c*h*s*'

# %%
ss.search(nwqm.make_query('FRGO STR CHS'))[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:FRGO STR CHS> stored,indexed,tokenized<web:Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese> stored,indexed,tokenized<mashed_web:frigocheeseheadslowmoisturepartskimoriginalmozzarellastringcheese cheeseheadslowmoisturepartskimoriginalmozzarellastringcheese headslowmoisturepartskimoriginalmozzarellastringcheese lowmoisturepartskimoriginalmozzarellastringcheese moisturepartskimoriginalmozzarellastringcheese partskimoriginalmozzarellastringcheese skimoriginalmozzarellastringcheese originalmozzarellastringcheese mozzarellastringcheese stringcheese cheese> stored,indexed,tokenized<unigrams:frigo cheese heads low moisture part skim original mozzarella string cheese> stored,indexed,tokenized<bigrams:mozzarella_string string_cheese> stored,indexed,tokenized<trigrams:mozzarella_string_cheese> stored,indexed,tokenized<ngrams:frigo cheese heads low moisture part skim original mozzarella string cheese mozzarella_string string_cheese mozzarella_string_cheese> stored<id:4171623216>>>

# %%
ss.explain(mwqm.make_query('FRGO STR CHS'))
# Out:
# mashed_web:f*r*g*o* mashed_web:s*t*r* mashed_web:c*h*s*
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 3.0
# 3.0 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 3.0
# 3.0 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Beef Choice For Stir Fry | BEEF STR FRY | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Galbani String Cheese | GLBNI STR CHS | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Kroger® Honey Citrus & Shea Butter Hand Soap Bottle | KRO SOAP | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth™ Natural Angus Beef Chuck Roast | STN CHCK RST | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Softsoap Kitchen Fresh Hands Citrus Extracts Antibacterial Hand Soap | SFTSOAP KTCHN FRSH | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Taylor Farms Roasted Garlic Chopped Salad Kit | TYFR SALAD KIT | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:f*r*g*o*
#   1.0 = mashed_web:c*h*s*
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Cholula Original Hot Sauce | CHOLULA HOT SAUCE | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Fancy Feast Classic Pate Cod Sole & Shrimp Feast Wet Cat Food | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Kroger® Pear & Coconut Hand Soap | KRO PEAR COCONUT | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Private Selection™ Campari Tomatoes | TOMATOES CAMPARI | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Simple Truth™ Pecan Halves | ST PECAN HLV RAW | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Smart Chicken Organic Ground Chicken 95% Lean | MBA CHK GROUND | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Softsoap Fresh Breeze Liquid Hand Soap | SFTSOAP KTCHN FRSH | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:s*t*r*
#
# ------------
# Taylor Farms Avocado Ranch Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:c*h*s*
#
# ------------

# %%
ss.explain(nwqm.make_query('FRGO STR CHS'))
# Out:
# web:f*r*g*o* bigrams:f*r*g*o* trigrams:f*r*g*o* web:s*t*r* bigrams:s*t*r* trigrams:s*t*r* web:c*h*s* bigrams:c*h*s* trigrams:c*h*s*
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 4.0
# 4.0 = sum of:
#   1.0 = web:f*r*g*o*
#   1.0 = web:s*t*r*
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Galbani String Cheese | GLBNI STR CHS | 3.0
# 3.0 = sum of:
#   1.0 = web:s*t*r*
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth™ Natural Angus Beef Chuck Roast | STN CHCK RST | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth™ Pecan Halves | ST PECAN HLV RAW | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Taylor Farms Avocado Ranch Chopped Salad Kit | TYFR SALAD KIT | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# Taylor Farms Roasted Garlic Chopped Salad Kit | TYFR SALAD KIT | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:s*t*r*
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 1.0
# 1.0 = sum of:
#   1.0 = web:s*t*r*
#
# ------------
# Beef Choice For Stir Fry | BEEF STR FRY | 1.0
# 1.0 = sum of:
#   1.0 = web:s*t*r*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = web:c*h*s*
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = web:s*t*r*
#
# ------------
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = web:c*h*s*
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 1.0
# 1.0 = sum of:
#   1.0 = web:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:s*t*r*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:c*h*s*
#
# ------------

# %%
ngram_wild_config = Config(nwqm, ss)

# %%
ngram_wild_score, ngram_wild_misses = evaluate(queries, ngram_wild_config, RAW_TO_WEB)

# %%
ngram_wild_score
# Out:
# 0.782608695652174

# %%
ngram_wild_misses
# Out:
# ['CA REDEM VAL',
#  'ARTICHOKES',
#  'ATKINS BARS',
#  'CUCUMBERS',
#  'KRO SOAP',
#  'KRO CCNT MK',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'ASP ORG',
#  'CABBAGE ORG',
#  'RADISH ORG',
#  'TOMATO ORGNC',
#  'STO CARROTS ORGNC',
#  'STN CHCK RST',
#  'MBA CHK GROUND']

# %%
set(ngram_wild_misses) - set(mashed_wild_misses)
# Out:
# {'ASP ORG',
#  'ATKINS BARS',
#  'CABBAGE ORG',
#  'KRO CCNT MK',
#  'MBA CHK GROUND',
#  'RADISH ORG',
#  'STN CHCK RST',
#  'TOMATO ORGNC'}

# %% [markdown]
# k*r*o* matches bigrams and trigrams for Kroger Spring Water getting a score of 3
# k*r*o* only matches unigrams for Kroger Premium Coconut Milk even though the score is still 3
# This indicates that unigrams should be boosted over bigrams, bigrams boosted over trigrams
# Alternative? More complex boolean query, like web:k*r*o* or (bigram:k*r*o* and not web:k*r*o*)

# %%
ss.explain(nwqm.make_query('KRO CCNT MK'))
# Out:
# web:k*r*o* bigrams:k*r*o* trigrams:k*r*o* web:c*c*n*t* bigrams:c*c*n*t* trigrams:c*c*n*t* web:m*k* bigrams:m*k* trigrams:m*k*
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 3.0
# 3.0 = sum of:
#   1.0 = web:k*r*o*
#   1.0 = bigrams:k*r*o*
#   1.0 = trigrams:k*r*o*
#
# ------------
# Kroger® Premium Coconut Milk | KRO CCNT MK | 3.0
# 3.0 = sum of:
#   1.0 = web:k*r*o*
#   1.0 = web:c*c*n*t*
#   1.0 = web:m*k*
#
# ------------
# Kroger® Romaine Leaf Single Cut Leaf | KRO ROMAINE | 3.0
# 3.0 = sum of:
#   1.0 = web:k*r*o*
#   1.0 = bigrams:k*r*o*
#   1.0 = trigrams:k*r*o*
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*c*n*t*
#   1.0 = trigrams:c*c*n*t*
#
# ------------
# Kroger® Pear & Coconut Hand Soap | KRO PEAR COCONUT | 2.0
# 2.0 = sum of:
#   1.0 = web:k*r*o*
#   1.0 = web:c*c*n*t*
#
# ------------
# Kroger® Romaine Lettuce Hearts | KRO ROMAINE | 2.0
# 2.0 = sum of:
#   1.0 = web:k*r*o*
#   1.0 = bigrams:k*r*o*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*c*n*t*
#   1.0 = trigrams:c*c*n*t*
#
# ------------
# Purina Fancy Feast Minced Turkey Feast in Sauce Wet Cat Food Can | FFST CAT FOOD | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:m*k*
#   1.0 = trigrams:m*k*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 2.0
# 2.0 = sum of:
#   1.0 = web:c*c*n*t*
#   1.0 = web:m*k*
#
# ------------
# Atkins Endulge Chocolate Coconut Treat Bar | ATKINS BARS | 1.0
# 1.0 = sum of:
#   1.0 = web:c*c*n*t*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:m*k*
#
# ------------
# Kroger® Honey Citrus & Shea Butter Hand Soap Bottle | KRO SOAP | 1.0
# 1.0 = sum of:
#   1.0 = web:k*r*o*
#
# ------------
# Kroger® Beef Shaved Steak | KRO BF STK SHAVED | 1.0
# 1.0 = sum of:
#   1.0 = web:k*r*o*
#
# ------------
# Kroger® Whole Baby Bella Mushrooms | MSHRM BYBL WHL | 1.0
# 1.0 = sum of:
#   1.0 = web:k*r*o*
#
# ------------
# Mountain High Plain Original Whole Milk Yoghurt | MOUNTAIN HGH YOGRT | 1.0
# 1.0 = sum of:
#   1.0 = web:m*k*
#
# ------------
# NO CHICKEN BROTH TETRA | OCEANS HALO BROTH | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:c*c*n*t*
#
# ------------
# Oscar Mayer Naturally Hardwood Smoked Bacon Mega Pack | OSCM BACON | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:m*k*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:c*c*n*t*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:c*c*n*t*
#
# ------------

# %%
ss.explain(nwqm.make_query('ASP ORG'))
# Out:
# web:a*s*p* bigrams:a*s*p* trigrams:a*s*p* web:o*r*g* bigrams:o*r*g* trigrams:o*r*g*
# Organic Italian Parsley | PARSLEY ORG | 3.0
# 3.0 = sum of:
#   1.0 = web:o*r*g*
#   1.0 = bigrams:o*r*g*
#   1.0 = trigrams:o*r*g*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 3.0
# 3.0 = sum of:
#   1.0 = web:o*r*g*
#   1.0 = bigrams:o*r*g*
#   1.0 = trigrams:o*r*g*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 3.0
# 3.0 = sum of:
#   1.0 = web:o*r*g*
#   1.0 = bigrams:o*r*g*
#   1.0 = trigrams:o*r*g*
#
# ------------
# Organic - Asparagus | ASP ORG | 2.0
# 2.0 = sum of:
#   1.0 = web:a*s*p*
#   1.0 = web:o*r*g*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 2.0
# 2.0 = sum of:
#   1.0 = web:o*r*g*
#   1.0 = bigrams:o*r*g*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 2.0
# 2.0 = sum of:
#   1.0 = web:o*r*g*
#   1.0 = bigrams:o*r*g*
#
# ------------
# Smart Chicken Organic Ground Chicken 95% Lean | MBA CHK GROUND | 2.0
# 2.0 = sum of:
#   1.0 = web:o*r*g*
#   1.0 = bigrams:o*r*g*
#
# ------------
# Cholula Original Hot Sauce | CHOLULA HOT SAUCE | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Mountain High Plain Original Whole Milk Yoghurt | MOUNTAIN HGH YOGRT | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Organic - Cabbage - Green | CABBAGE ORG | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Organic - Cabbage - Red | CABBAGE ORG | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Organic - Parsley - Curly | PARSLEY ORG | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Organic - Peppers - Green Bell | PPRS BL GRN ORGN | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Organic - Radishes | RADISH ORG | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Organic - Squash - Yellow | SQSH YLW ORG | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Organic - Tomatoes - On the Vine | TOMATO ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Pero Organic Green Beans | GREEN BEANS ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = web:o*r*g*
#
# ------------

# %% [markdown]
# ## XOR Ngram Wild Query Maker

# %%
xnwqm = XorNgramWildQueryMaker(WORDS)

# %%
xnwqm.make_query('FRGO STR CHS')
# Out:
# '(web:f*r*g*o* bigrams:f*r*g*o* trigrams:f*r*g*o*) OR (web:s*t*r* bigrams:s*t*r* trigrams:s*t*r*) OR (web:c*h*s* bigrams:c*h*s* trigrams:c*h*s*)'

# %%
ss.search(nwqm.make_query('FRGO STR CHS'))[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:FRGO STR CHS> stored,indexed,tokenized<web:Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese> stored,indexed,tokenized<mashed_web:frigocheeseheadslowmoisturepartskimoriginalmozzarellastringcheese cheeseheadslowmoisturepartskimoriginalmozzarellastringcheese headslowmoisturepartskimoriginalmozzarellastringcheese lowmoisturepartskimoriginalmozzarellastringcheese moisturepartskimoriginalmozzarellastringcheese partskimoriginalmozzarellastringcheese skimoriginalmozzarellastringcheese originalmozzarellastringcheese mozzarellastringcheese stringcheese cheese> stored,indexed,tokenized<unigrams:frigo cheese heads low moisture part skim original mozzarella string cheese> stored,indexed,tokenized<bigrams:mozzarella_string string_cheese> stored,indexed,tokenized<trigrams:mozzarella_string_cheese> stored,indexed,tokenized<ngrams:frigo cheese heads low moisture part skim original mozzarella string cheese mozzarella_string string_cheese mozzarella_string_cheese> stored<id:4171623216>>>

# %%
ss.explain(xnwqm.make_query('FRGO STR CHS'))
# Out:
# (web:f*r*g*o* bigrams:f*r*g*o* trigrams:f*r*g*o*) OR (web:s*t*r* bigrams:s*t*r* trigrams:s*t*r*) OR (web:c*h*s* bigrams:c*h*s* trigrams:c*h*s*)
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 4.0
# 4.0 = sum of:
#   1.0 = web:f*r*g*o*
#   1.0 = web:s*t*r*
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Galbani String Cheese | GLBNI STR CHS | 3.0
# 3.0 = sum of:
#   1.0 = web:s*t*r*
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth™ Natural Angus Beef Chuck Roast | STN CHCK RST | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth™ Pecan Halves | ST PECAN HLV RAW | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = trigrams:s*t*r*
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:s*t*r*
#   1.0 = web:c*h*s*
#
# ------------
# Taylor Farms Avocado Ranch Chopped Salad Kit | TYFR SALAD KIT | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# Taylor Farms Roasted Garlic Chopped Salad Kit | TYFR SALAD KIT | 2.0
# 2.0 = sum of:
#   1.0 = bigrams:c*h*s*
#   1.0 = trigrams:c*h*s*
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:s*t*r*
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 1.0
# 1.0 = sum of:
#   1.0 = web:s*t*r*
#
# ------------
# Beef Choice For Stir Fry | BEEF STR FRY | 1.0
# 1.0 = sum of:
#   1.0 = web:s*t*r*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = web:c*h*s*
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = web:s*t*r*
#
# ------------
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = web:c*h*s*
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 1.0
# 1.0 = sum of:
#   1.0 = web:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:s*t*r*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = bigrams:c*h*s*
#
# ------------

# %% [markdown]
# ## Boosted ngrams

# %%
bnwqm = BoostedNgramWildQueryMaker(WORDS)

# %%
bnwqm.make_query('FRGO STR CHS')
# Out:
# 'ngrams:f*r*g*o* OR ngrams:s*t*r* OR ngrams:c*h*s*'

# %%
ss.search(bnwqm.make_query('FRGO STR CHS'))[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:FRGO STR CHS> stored,indexed,tokenized<web:Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese> stored,indexed,tokenized<mashed_web:frigocheeseheadslowmoisturepartskimoriginalmozzarellastringcheese cheeseheadslowmoisturepartskimoriginalmozzarellastringcheese headslowmoisturepartskimoriginalmozzarellastringcheese lowmoisturepartskimoriginalmozzarellastringcheese moisturepartskimoriginalmozzarellastringcheese partskimoriginalmozzarellastringcheese skimoriginalmozzarellastringcheese originalmozzarellastringcheese mozzarellastringcheese stringcheese cheese> stored,indexed,tokenized<unigrams:frigo cheese heads low moisture part skim original mozzarella string cheese> stored,indexed,tokenized<bigrams:mozzarella_string string_cheese> stored,indexed,tokenized<trigrams:mozzarella_string_cheese> stored,indexed,tokenized<ngrams:frigo cheese heads low moisture part skim original mozzarella string cheese mozzarella_string string_cheese mozzarella_string_cheese> stored<id:4171623216>>>

# %%
ss.search(bnwqm.make_query('GLBNI STR CHS'))[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:GLBNI STR CHS> stored,indexed,tokenized<web:Galbani String Cheese> stored,indexed,tokenized<mashed_web:galbanistringcheese stringcheese cheese> stored,indexed,tokenized<unigrams:galbani string cheese> stored,indexed,tokenized<bigrams:galbani_string string_cheese> stored,indexed,tokenized<trigrams:galbani_string_cheese> stored,indexed,tokenized<ngrams:galbani string cheese galbani_string string_cheese galbani_string_cheese> stored<id:7403006610>>>

# %%
ss.explain(bnwqm.make_query('FRGO STR CHS'))
# Out:
# ngrams:f*r*g*o* OR ngrams:s*t*r* OR ngrams:c*h*s*
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 3.0
# 3.0 = sum of:
#   1.0 = ngrams:f*r*g*o*
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Galbani String Cheese | GLBNI STR CHS | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Beef Choice For Stir Fry | BEEF STR FRY | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth™ Natural Angus Beef Chuck Roast | STN CHCK RST | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth™ Pecan Halves | ST PECAN HLV RAW | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Taylor Farms Avocado Ranch Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Taylor Farms Roasted Garlic Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------

# %%
ss.explain(bnwqm.make_query('GLBNI STR CHS'))
# Out:
# ngrams:g*l*b*n*i* OR ngrams:s*t*r* OR ngrams:c*h*s*
# Galbani String Cheese | GLBNI STR CHS | 3.0
# 3.0 = sum of:
#   1.0 = ngrams:g*l*b*n*i*
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Beef Choice For Stir Fry | BEEF STR FRY | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth™ Natural Angus Beef Chuck Roast | STN CHCK RST | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth™ Pecan Halves | ST PECAN HLV RAW | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Taylor Farms Avocado Ranch Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Taylor Farms Roasted Garlic Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------

# %%
ss.search(bnwqm.make_query('FRGO STR CHS'))[0]
# Out:
# <Document: Document<stored,indexed,tokenized,indexOptions=DOCS_AND_FREQS<raw:FRGO STR CHS> stored,indexed,tokenized<web:Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese> stored,indexed,tokenized<mashed_web:frigocheeseheadslowmoisturepartskimoriginalmozzarellastringcheese cheeseheadslowmoisturepartskimoriginalmozzarellastringcheese headslowmoisturepartskimoriginalmozzarellastringcheese lowmoisturepartskimoriginalmozzarellastringcheese moisturepartskimoriginalmozzarellastringcheese partskimoriginalmozzarellastringcheese skimoriginalmozzarellastringcheese originalmozzarellastringcheese mozzarellastringcheese stringcheese cheese> stored,indexed,tokenized<unigrams:frigo cheese heads low moisture part skim original mozzarella string cheese> stored,indexed,tokenized<bigrams:mozzarella_string string_cheese> stored,indexed,tokenized<trigrams:mozzarella_string_cheese> stored,indexed,tokenized<ngrams:frigo cheese heads low moisture part skim original mozzarella string cheese mozzarella_string string_cheese mozzarella_string_cheese> stored<id:4171623216>>>

# %%
bngram_wild_config = Config(bnwqm, ss)

# %%
bngram_wild_score, bngram_wild_misses = evaluate(queries, bngram_wild_config, RAW_TO_WEB)

# %%
bngram_wild_score
# Out:
# 0.8985507246376812

# %%
bngram_wild_misses
# Out:
# ['CA REDEM VAL',
#  'ARTICHOKES',
#  'CUCUMBERS',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'STO CARROTS ORGNC']

# %%
mashed_wild_misses
# Out:
# ['CA REDEM VAL',
#  'ARTICHOKES',
#  'CUCUMBERS',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'PRSL MUENSTR',
#  'STO CARROTS ORGNC']

# %%
ss.explain(mwqm.make_query('PRSL MUENSTR'))
# Out:
# mashed_web:p*r*s*l* mashed_web:m*u*e*n*s*t*r*
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#   1.0 = mashed_web:m*u*e*n*s*t*r*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#   1.0 = mashed_web:m*u*e*n*s*t*r*
#
# ------------
# Earthwise Palm Trees Reusable Shopping Bag | PALM SHOPPING BAGS | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Organic - Parsley - Curly | PARSLEY ORG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Organic Italian Parsley | PARSLEY ORG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Private Selection™ Campari Tomatoes | TOMATOES CAMPARI | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Classic Pate Savory Salmon Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Classic Pate Tender Beef Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = mashed_web:p*r*s*l*
#
# ------------

# %%
ss.explain(bnwqm.make_query('PRSL MUENSTR'))
# Out:
# ngrams:p*r*s*l* OR ngrams:m*u*e*n*s*t*r*
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:p*r*s*l*
#   1.0 = ngrams:m*u*e*n*s*t*r*
#
# ------------
# Organic - Parsley - Curly | PARSLEY ORG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*r*s*l*
#
# ------------
# Organic Italian Parsley | PARSLEY ORG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*r*s*l*
#
# ------------
# Private Selection™ Campari Tomatoes | TOMATOES CAMPARI | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*r*s*l*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*r*s*l*
#
# ------------
# Purina Fancy Feast Classic Pate Savory Salmon Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*r*s*l*
#
# ------------

# %%
wild_misses
# Out:
# ['CA REDEM VAL',
#  'ARTICHOKES',
#  'BRHD CHEESE',
#  'CUCUMBERS',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'PRSL MUENSTR',
#  'STO CCNT MILK',
#  'STO BROTH',
#  'STO CARROTS ORGNC']

# %%
ss.explain(bnwqm.make_query('KRO SOAP'))
# Out:
# ngrams:k*r*o* OR soap^1.0
# Kroger® Pear & Coconut Hand Soap | KRO PEAR COCONUT | 2.3123726844787598
# 2.3123727 = sum of:
#   1.0 = ngrams:k*r*o*
#   1.3123727 = weight(web:soap in 29) [BM25Similarity], result of:
#     1.3123727 = score(freq=1.0), product of:
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Kroger® Honey Citrus & Shea Butter Hand Soap Bottle | KRO SOAP | 2.084866762161255
# 2.0848668 = sum of:
#   1.0 = ngrams:k*r*o*
#   1.0848668 = weight(web:soap in 27) [BM25Similarity], result of:
#     1.0848668 = score(freq=1.0), product of:
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Softsoap Fresh Breeze Liquid Hand Soap | SFTSOAP KTCHN FRSH | 1.3123726844787598
# 1.3123727 = sum of:
#   1.3123727 = weight(web:soap in 76) [BM25Similarity], result of:
#     1.3123727 = score(freq=1.0), product of:
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Softsoap Kitchen Fresh Hands Citrus Extracts Antibacterial Hand Soap | SFTSOAP KTCHN FRSH | 1.0848667621612549
# 1.0848668 = sum of:
#   1.0848668 = weight(web:soap in 77) [BM25Similarity], result of:
#     1.0848668 = score(freq=1.0), product of:
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:k*r*o*
#
# ------------
# Kroger® Beef Shaved Steak | KRO BF STK SHAVED | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:k*r*o*
#
# ------------
# Kroger® Premium Coconut Milk | KRO CCNT MK | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:k*r*o*
#
# ------------
# Kroger® Romaine Leaf Single Cut Leaf | KRO ROMAINE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:k*r*o*
#
# ------------
# Kroger® Romaine Lettuce Hearts | KRO ROMAINE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:k*r*o*
#
# ------------
# Kroger® Whole Baby Bella Mushrooms | MSHRM BYBL WHL | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:k*r*o*
#
# ------------

# %%
ss.explain(bnwqm.make_query('LES PET CHEESE BAR'))
# Out:
# les^1.0 OR ngrams:p*e*t* OR cheese^1.0 OR bar^1.0
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 3.9276785850524902
# 3.9276786 = sum of:
#   1.6932418 = weight(web:les in 34) [BM25Similarity], result of:
#     1.6932418 = score(freq=1.0), product of:
#       3.5263605 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         2 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = ngrams:p*e*t*
#   1.2344369 = weight(web:cheese in 34) [BM25Similarity], result of:
#     1.2344369 = score(freq=1.0), product of:
#       2.5708492 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         6 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 3.7230255603790283
# 3.7230256 = sum of:
#   1.5748794 = weight(web:les in 35) [BM25Similarity], result of:
#     1.5748794 = score(freq=1.0), product of:
#       3.5263605 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         2 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = ngrams:p*e*t*
#   1.1481462 = weight(web:cheese in 35) [BM25Similarity], result of:
#     1.1481462 = score(freq=1.0), product of:
#       2.5708492 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         6 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0731310844421387
# 2.073131 = sum of:
#   1.0 = ngrams:p*e*t*
#   1.0731312 = weight(web:cheese in 59) [BM25Similarity], result of:
#     1.0731312 = score(freq=1.0), product of:
#       2.5708492 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         6 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Atkins Endulge Chocolate Coconut Treat Bar | ATKINS BARS | 1.803015112876892
# 1.8030151 = sum of:
#   1.8030151 = weight(web:bar in 8) [BM25Similarity], result of:
#     1.8030151 = score(freq=1.0), product of:
#       4.037186 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         1 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Galbani String Cheese | GLBNI STR CHS | 1.452813982963562
# 1.452814 = sum of:
#   1.452814 = weight(web:cheese in 25) [BM25Similarity], result of:
#     1.452814 = score(freq=1.0), product of:
#       2.5708492 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         6 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 1.278476357460022
# 1.2784764 = sum of:
#   1.2784764 = weight(web:cheese in 24) [BM25Similarity], result of:
#     1.2784764 = score(freq=2.0), product of:
#       2.5708492 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         6 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.4972973 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         2.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Nut Pods Hazelnut Unsweetened Dairy-Free Creamer | NUTPODS CREAMER | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Private Selection™ Campari Tomatoes | TOMATOES CAMPARI | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Purina Fancy Feast Classic Pate Savory Salmon Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Purina Fancy Feast Classic Pate Tender Beef Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Purina Fancy Feast Minced Turkey Feast in Sauce Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:p*e*t*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 0.949109673500061
# 0.9491097 = sum of:
#   0.9491097 = weight(web:cheese in 13) [BM25Similarity], result of:
#     0.9491097 = score(freq=1.0), product of:
#       2.5708492 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         6 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.3691814 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         9.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------

# %%
wild_score
# Out:
# 0.8405797101449275

# %%
mashed_wild_score
# Out:
# 0.8840579710144928

# %%
set(bngram_wild_misses) - set(mashed_wild_misses)
# Out:
# set()

# %%
set(mashed_wild_misses) - set(bngram_wild_misses)
# Out:
# {'PRSL MUENSTR'}

# %%
ss.explain(bnwqm.make_query('GLBNI STR CHS'))
# Out:
# ngrams:g*l*b*n*i* OR ngrams:s*t*r* OR ngrams:c*h*s*
# Galbani String Cheese | GLBNI STR CHS | 3.0
# 3.0 = sum of:
#   1.0 = ngrams:g*l*b*n*i*
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Frigo Cheese Heads Low Moisture Part Skim Original Mozzarella String Cheese | FRGO STR CHS | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 2.0
# 2.0 = sum of:
#   1.0 = ngrams:s*t*r*
#   1.0 = ngrams:c*h*s*
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Beef Choice For Stir Fry | BEEF STR FRY | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Boar's Head Monterey Jack with Jalapeno Pre-Sliced Cheese | BRHD CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Fancy Feast Classic Pate Tender Liver & Chicken Feast Wet Cat Food | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Les Petites Havarati Cheese Wedge | LES PET CHEESE | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Les Petites Kosher Colby Jack Cheese | LES PET CHEESE BAR | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Purina Fancy Feast Classic Pate Chicken Feast Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Purina Fancy Feast Sliced Chicken Hearts & Liver Feast in Gravy Wet Cat Food Can | FFST CAT FOOD | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth™ Natural Angus Beef Chuck Roast | STN CHCK RST | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Simple Truth™ Pecan Halves | ST PECAN HLV RAW | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*r*
#
# ------------
# Taylor Farms Avocado Ranch Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------
# Taylor Farms Roasted Garlic Chopped Salad Kit | TYFR SALAD KIT | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:c*h*s*
#
# ------------

# %% [markdown]
# ## Fuzzy ngrams

# %%
fnwqm = FuzzyNgramWildQueryMaker(WORDS)

# %%
fnwqm.make_query('ARTICHOKES')
# Out:
# 'ngrams:a*r*t*i*c*h*o*k*e*s* OR artichokes~'

# %%
fngram_wild_config = Config(fnwqm, ss)

# %%
fngram_wild_score, fngram_wild_misses = evaluate(queries, fngram_wild_config, RAW_TO_WEB)

# %%
fngram_wild_score
# Out:
# 0.927536231884058

# %%
fngram_wild_misses
# Out:
# ['CA REDEM VAL',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'STO CARROTS ORGNC']

# %%
bngram_wild_misses
# Out:
# ['CA REDEM VAL',
#  'ARTICHOKES',
#  'CUCUMBERS',
#  'KRO SOAP',
#  'LES PET CHEESE BAR',
#  'BROWN ONIONS',
#  'STO CARROTS ORGNC']

# %%
eliminees = set(bngram_wild_misses) - set(fngram_wild_misses)
eliminees
# Out:
# {'ARTICHOKES', 'CUCUMBERS'}

# %%
regressions = set(fngram_wild_misses) - set(bngram_wild_misses)
regressions
# Out:
# set()

# %%
ss.explain(fnwqm.make_query('STO CARROTS ORGNC'))
# Out:
# ngrams:s*t*o* OR sto~ OR carrots^1.0 OR ngrams:o*r*g*n*c* OR orgnc~
# Simple Truth Organic™ Baby Carrots | STO CRT BABY ORGNC | 3.983488082885742
# 3.983488 = sum of:
#   1.0 = ngrams:s*t*o*
#   1.5748794 = weight(web:carrots in 65) [BM25Similarity], result of:
#     1.5748794 = score(freq=1.0), product of:
#       3.5263605 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         2 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = ngrams:o*r*g*n*c*
#   0.40860876 = weight(web:organic in 65) [BM25Similarity], result of:
#     0.40860876 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Whole Carrots | STO CARROTS ORGNC | 3.983488082885742
# 3.983488 = sum of:
#   1.0 = ngrams:s*t*o*
#   1.5748794 = weight(web:carrots in 71) [BM25Similarity], result of:
#     1.5748794 = score(freq=1.0), product of:
#       3.5263605 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         2 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = ngrams:o*r*g*n*c*
#   0.40860876 = weight(web:organic in 71) [BM25Similarity], result of:
#     0.40860876 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Fat Free Beef Stock | STO STOCK | 2.7422897815704346
# 2.7422898 = sum of:
#   1.0 = ngrams:s*t*o*
#   0.38380006 = weight(web:stock in 69) [BM25Similarity], result of:
#     0.38380006 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.39182281 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         8.0 = dl, length of field
#         5.75 = avgdl, average length of field
#   1.0 = ngrams:o*r*g*n*c*
#   0.3584898 = weight(web:organic in 69) [BM25Similarity], result of:
#     0.3584898 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.39182281 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         8.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Basil | STO BASIL | 2.4393184185028076
# 2.4393184 = sum of:
#   1.0 = ngrams:s*t*o*
#   1.0 = ngrams:o*r*g*n*c*
#   0.4393184 = weight(web:organic in 67) [BM25Similarity], result of:
#     0.4393184 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Coconut Milk | STO CCNT MILK | 2.4086086750030518
# 2.4086087 = sum of:
#   1.0 = ngrams:s*t*o*
#   1.0 = ngrams:o*r*g*n*c*
#   0.40860876 = weight(web:organic in 68) [BM25Similarity], result of:
#     0.40860876 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Baby Spring Mix | STO BABY SPRING MX | 2.3819119930267334
# 2.381912 = sum of:
#   1.0 = ngrams:s*t*o*
#   1.0 = ngrams:o*r*g*n*c*
#   0.38191202 = weight(web:organic in 66) [BM25Similarity], result of:
#     0.38191202 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth Organic™ Fat Free Free Range Chicken Broth | STO BROTH | 2.3193225860595703
# 2.3193226 = sum of:
#   1.0 = ngrams:s*t*o*
#   1.0 = ngrams:o*r*g*n*c*
#   0.31932247 = weight(web:organic in 70) [BM25Similarity], result of:
#     0.31932247 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.34901363 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         10.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Asparagus | ASP ORG | 1.5672062635421753
# 1.5672063 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.56720626 = weight(web:organic in 45) [BM25Similarity], result of:
#     0.56720626 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.61994606 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         2.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Radishes | RADISH ORG | 1.5672062635421753
# 1.5672063 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.56720626 = weight(web:organic in 50) [BM25Similarity], result of:
#     0.56720626 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.61994606 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         2.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Cabbage - Green | CABBAGE ORG | 1.517035722732544
# 1.5170357 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.51703566 = weight(web:organic in 46) [BM25Similarity], result of:
#     0.51703566 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Cabbage - Red | CABBAGE ORG | 1.517035722732544
# 1.5170357 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.51703566 = weight(web:organic in 47) [BM25Similarity], result of:
#     0.51703566 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Parsley - Curly | PARSLEY ORG | 1.517035722732544
# 1.5170357 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.51703566 = weight(web:organic in 48) [BM25Similarity], result of:
#     0.51703566 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Squash - Yellow | SQSH YLW ORG | 1.517035722732544
# 1.5170357 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.51703566 = weight(web:organic in 51) [BM25Similarity], result of:
#     0.51703566 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic Italian Parsley | PARSLEY ORG | 1.517035722732544
# 1.5170357 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.51703566 = weight(web:organic in 53) [BM25Similarity], result of:
#     0.51703566 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.56511056 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         3.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Peppers - Green Bell | PPRS BL GRN ORGN | 1.4750192165374756
# 1.4750192 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.47501922 = weight(web:organic in 49) [BM25Similarity], result of:
#     0.47501922 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.51918733 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         4.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Pero Organic Green Beans | GREEN BEANS ORGNC | 1.4750192165374756
# 1.4750192 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.47501922 = weight(web:organic in 56) [BM25Similarity], result of:
#     0.47501922 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.51918733 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         4.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Organic - Tomatoes - On the Vine | TOMATO ORGNC | 1.4393184185028076
# 1.4393184 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.4393184 = weight(web:organic in 52) [BM25Similarity], result of:
#     0.4393184 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Smart Chicken Organic Ground Chicken 95% Lean | MBA CHK GROUND | 1.3819119930267334
# 1.381912 = sum of:
#   1.0 = ngrams:o*r*g*n*c*
#   0.38191202 = weight(web:organic in 75) [BM25Similarity], result of:
#     0.38191202 = score(freq=1.0), product of:
#       0.6 = boost
#       1.5248805 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         18 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Hefty Storage Slider Bags | HEFTY STORAGE BAG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*o*
#
# ------------
# Private Selection™ Campari Tomatoes | TOMATOES CAMPARI | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*o*
#
# ------------
# Private Selection™ Grab & Go Maple Turkey Breast | PRSL MPL TKY GNG | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*o*
#   0.0 = ConstantScore(web:go)^0.0
#
# ------------
# Private Selection™ Grab & Go Muenster Cheese | PRSL MUENSTR | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*o*
#   0.0 = ConstantScore(web:go)^0.0
#
# ------------
# Softsoap Fresh Breeze Liquid Hand Soap | SFTSOAP KTCHN FRSH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*o*
#
# ------------
# Softsoap Kitchen Fresh Hands Citrus Extracts Antibacterial Hand Soap | SFTSOAP KTCHN FRSH | 1.0
# 1.0 = sum of:
#   1.0 = ngrams:s*t*o*
#
# ------------
# Cholula Original Hot Sauce | CHOLULA HOT SAUCE | 0.5085567235946655
# 0.5085567 = sum of:
#   0.5085567 = weight(web:hot in 17) [BM25Similarity], result of:
#     0.5085567 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.51918733 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         4.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Beef Choice For Stir Fry | BEEF STR FRY | 0.47033533453941345
# 0.47033533 = sum of:
#   0.47033533 = weight(web:stir in 10) [BM25Similarity], result of:
#     0.47033533 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.48016697 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         5.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) Essentia Ionized Alkaline Water | ESNT WATER | 0.4374575614929199
# 0.43745756 = sum of:
#   0.43745756 = weight(web:qty in 0) [BM25Similarity], result of:
#     0.43745756 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) FIJI Natural Artesian Water | FIJI WATER | 0.4374575614929199
# 0.43745756 = sum of:
#   0.43745756 = weight(web:qty in 1) [BM25Similarity], result of:
#     0.43745756 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) Kroger® Spring Water | KRO WATER | 0.4374575614929199
# 0.43745756 = sum of:
#   0.43745756 = weight(web:qty in 2) [BM25Similarity], result of:
#     0.43745756 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.44660193 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         6.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Beyond Meat Hot Italian Plant-Based Sausage | BYND SSG HT ITLN | 0.4088759422302246
# 0.40887594 = sum of:
#   0.40887594 = weight(web:hot in 11) [BM25Similarity], result of:
#     0.40887594 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# Simple Truth™ Sea Salt Roasted Cashews | ST CASHEWS RS | 0.4088759422302246
# 0.40887594 = sum of:
#   0.40887594 = weight(web:sea in 74) [BM25Similarity], result of:
#     0.40887594 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.41742286 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         7.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# (LMTD QTY) Robitussin Max Strength Blue Raspberry Nighttime Cough DM Liquid | ROBITUSSIN COUGH | 0.3241592049598694
# 0.3241592 = sum of:
#   0.3241592 = weight(web:qty in 3) [BM25Similarity], result of:
#     0.3241592 = score(freq=1.0), product of:
#       0.3333333 = boost
#       2.9385738 = idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#         4 = n, number of documents containing term
#         84 = N, total number of documents with field
#       0.33093524 = tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#         1.0 = freq, occurrences of term within document
#         1.2 = k1, term saturation parameter
#         0.75 = b, length normalization parameter
#         11.0 = dl, length of field
#         5.75 = avgdl, average length of field
#
# ------------
# NO CHICKEN BROTH TETRA | OCEANS HALO BROTH | 0.0
# 0.0 = sum of:
#   0.0 = ConstantScore(web:no)^0.0
#
# ------------
