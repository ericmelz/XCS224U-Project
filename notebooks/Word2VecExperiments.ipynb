# %% [markdown]
# # Word2Vec Tutorial
# Following https://rare-technologies.com/word2vec-tutorial/

# %%
import gensim, logging

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
sentences = [['first', 'sentence'], ['second', 'sentence']]

# %%
# train word2Vec on the 2 sentences
model = gensim.models.Word2Vec(sentences, min_count=1)
# Out:
# 2020-04-28 19:07:59,580 : INFO : collecting all words and their counts
# 2020-04-28 19:07:59,581 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-28 19:07:59,581 : INFO : collected 3 word types from a corpus of 4 raw words and 2 sentences
# 2020-04-28 19:07:59,582 : INFO : Loading a fresh vocabulary
# 2020-04-28 19:07:59,582 : INFO : effective_min_count=1 retains 3 unique words (100% of original 3, drops 0)
# 2020-04-28 19:07:59,582 : INFO : effective_min_count=1 leaves 4 word corpus (100% of original 4, drops 0)
# 2020-04-28 19:07:59,583 : INFO : deleting the raw counts dictionary of 3 items
# 2020-04-28 19:07:59,583 : INFO : sample=0.001 downsamples 3 most-common words
# 2020-04-28 19:07:59,583 : INFO : downsampling leaves estimated 0 word corpus (5.7% of prior 4)
# 2020-04-28 19:07:59,584 : INFO : estimated required memory for 3 words and 100 dimensions: 3900 bytes
# 2020-04-28 19:07:59,584 : INFO : resetting layer weights
# 2020-04-28 19:07:59,585 : INFO : training model with 3 workers on 3 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-04-28 19:07:59,588 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 19:07:59,588 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 19:07:59,588 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 19:07:59,589 : INFO : EPOCH - 1 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2020-04-28 19:07:59,590 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 19:07:59,591 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 19:07:59,591 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 19:07:59,591 : INFO : EPOCH - 2 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2020-04-28 19:07:59,593 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 19:07:59,593 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 19:07:59,594 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 19:07:59,594 : INFO : EPOCH - 3 : training on 4 raw words (1 effective words) took 0.0s, 665 effective words/s
# 2020-04-28 19:07:59,596 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 19:07:59,596 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 19:07:59,597 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 19:07:59,597 : INFO : EPOCH - 4 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2020-04-28 19:07:59,599 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 19:07:59,599 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 19:07:59,599 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 19:07:59,600 : INFO : EPOCH - 5 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2020-04-28 19:07:59,600 : INFO : training on a 20 raw words (1 effective words) took 0.0s, 70 effective words/s
# 2020-04-28 19:07:59,600 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model.save('/tmp/mymodel')
# Out:
# 2020-04-28 19:27:35,801 : INFO : saving Word2Vec object under /tmp/mymodel, separately None
# 2020-04-28 19:27:35,802 : INFO : not storing attribute vectors_norm
# 2020-04-28 19:27:35,803 : INFO : not storing attribute cum_table
# 2020-04-28 19:27:35,805 : INFO : saved /tmp/mymodel

# %%
new_model = gensim.models.Word2Vec.load('/tmp/mymodel')
# Out:
# 2020-04-28 19:27:45,650 : INFO : loading Word2Vec object from /tmp/mymodel
# 2020-04-28 19:27:45,651 : INFO : loading wv recursively from /tmp/mymodel.wv.* with mmap=None
# 2020-04-28 19:27:45,652 : INFO : setting ignored attribute vectors_norm to None
# 2020-04-28 19:27:45,652 : INFO : loading vocabulary recursively from /tmp/mymodel.vocabulary.* with mmap=None
# 2020-04-28 19:27:45,653 : INFO : loading trainables recursively from /tmp/mymodel.trainables.* with mmap=None
# 2020-04-28 19:27:45,653 : INFO : setting ignored attribute cum_table to None
# 2020-04-28 19:27:45,653 : INFO : loaded /tmp/mymodel

# %%
model.similarity('first', 'second')
# Out:
# /home/ubuntu/anaconda3/envs/nlu/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# -0.069061086

# %%
model.similarity('first', 'sentence')
# Out:
# /home/ubuntu/anaconda3/envs/nlu/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# -0.0078044254

# %%
model['first']
# Out:
# /home/ubuntu/anaconda3/envs/nlu/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-5.1557651e-04, -2.6061535e-03, -2.2290575e-03, -3.5140431e-05,
#        -3.5001715e-03, -3.2925140e-03, -3.2704154e-03,  2.9731002e-03,
#         2.8313864e-03,  1.7160014e-04,  3.0552052e-04, -4.1806176e-03,
#        -2.5628280e-04, -2.7225162e-03,  2.9707816e-04,  8.3405717e-04,
#        -9.7546814e-04, -3.9576604e-03, -1.8852463e-03, -8.5335545e-04,
#        -4.1023158e-03,  1.4865092e-03,  1.8346042e-04,  4.3650451e-03,
#         6.1661669e-04,  8.9580764e-04,  4.7157751e-03, -4.4615977e-03,
#         1.1433013e-03, -4.9245879e-03, -2.5632298e-03, -2.8972991e-03,
#         1.2104673e-03,  1.3076308e-03, -1.3947985e-04,  4.7516855e-03,
#         3.5329117e-03,  3.4518333e-04,  3.5774116e-03, -4.3694666e-03,
#        -4.0800171e-03,  3.5351724e-03,  3.4319721e-03, -2.6409563e-03,
#        -3.5992175e-04,  4.8676943e-03,  1.4481074e-03, -4.6682209e-03,
#        -2.6874815e-03,  9.9697325e-04,  7.8563811e-04, -1.0971050e-04,
#        -1.8902803e-03,  3.3627409e-03, -4.3316414e-03,  4.4663106e-03,
#         1.6967950e-03,  4.7797785e-04, -4.1211010e-03, -3.2848283e-03,
#         4.7502713e-03, -4.7504380e-03,  4.1539087e-03,  5.0885975e-04,
#         4.6973987e-03, -3.0867400e-04,  4.4516763e-03,  1.0969492e-03,
#         1.0738668e-03, -4.0487084e-03,  2.7656176e-03, -1.3027862e-03,
#         4.8031213e-04,  9.9338038e-05,  2.3860866e-03, -5.7368161e-04,
#        -8.9091505e-04, -3.5076521e-03,  9.6717995e-04, -3.3914205e-03,
#        -1.7839960e-03,  1.3857131e-03, -6.8330852e-04,  4.5981547e-03,
#        -2.1276746e-03,  3.0926676e-03, -4.8292438e-03,  1.2057781e-03,
#         1.4260319e-03,  1.0129977e-03,  4.5726732e-03,  3.0693109e-03,
#         4.9747746e-03,  4.7345031e-03,  4.3814184e-04,  7.0441567e-04,
#         3.9823116e-03, -1.4354392e-03,  1.5188399e-03,  3.3138527e-03],
#       dtype=float32)

# %% [markdown]
# ## From gensim docs
# https://radimrehurek.com/gensim/models/word2vec.html

# %%
from gensim.test.utils import common_texts
from gensim.models import Word2Vec

# %%
model = Word2Vec(common_texts, size=100, window=5, min_count=1, workers=4)
# Out:
# 2020-04-28 20:32:04,979 : INFO : collecting all words and their counts
# 2020-04-28 20:32:04,980 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-28 20:32:04,980 : INFO : collected 12 word types from a corpus of 29 raw words and 9 sentences
# 2020-04-28 20:32:04,981 : INFO : Loading a fresh vocabulary
# 2020-04-28 20:32:04,981 : INFO : effective_min_count=1 retains 12 unique words (100% of original 12, drops 0)
# 2020-04-28 20:32:04,982 : INFO : effective_min_count=1 leaves 29 word corpus (100% of original 29, drops 0)
# 2020-04-28 20:32:04,982 : INFO : deleting the raw counts dictionary of 12 items
# 2020-04-28 20:32:04,983 : INFO : sample=0.001 downsamples 12 most-common words
# 2020-04-28 20:32:04,983 : INFO : downsampling leaves estimated 3 word corpus (12.1% of prior 29)
# 2020-04-28 20:32:04,983 : INFO : estimated required memory for 12 words and 100 dimensions: 15600 bytes
# 2020-04-28 20:32:04,984 : INFO : resetting layer weights
# 2020-04-28 20:32:04,986 : INFO : training model with 4 workers on 12 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-04-28 20:32:04,988 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-28 20:32:04,989 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 20:32:04,989 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 20:32:04,990 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 20:32:04,990 : INFO : EPOCH - 1 : training on 29 raw words (3 effective words) took 0.0s, 1883 effective words/s
# 2020-04-28 20:32:04,992 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-28 20:32:04,992 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 20:32:04,993 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 20:32:04,993 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 20:32:04,993 : INFO : EPOCH - 2 : training on 29 raw words (3 effective words) took 0.0s, 1654 effective words/s
# 2020-04-28 20:32:04,995 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-28 20:32:04,996 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 20:32:04,996 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 20:32:04,996 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 20:32:04,997 : INFO : EPOCH - 3 : training on 29 raw words (1 effective words) took 0.0s, 598 effective words/s
# 2020-04-28 20:32:04,999 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-28 20:32:04,999 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 20:32:05,000 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 20:32:05,000 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 20:32:05,000 : INFO : EPOCH - 4 : training on 29 raw words (4 effective words) took 0.0s, 2162 effective words/s
# 2020-04-28 20:32:05,002 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-04-28 20:32:05,003 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 20:32:05,003 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 20:32:05,003 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 20:32:05,004 : INFO : EPOCH - 5 : training on 29 raw words (6 effective words) took 0.0s, 3272 effective words/s
# 2020-04-28 20:32:05,004 : INFO : training on a 145 raw words (17 effective words) took 0.0s, 993 effective words/s
# 2020-04-28 20:32:05,004 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
vector = model.wv['computer']

# %%
vector
# Out:
# array([-1.6001988e-03,  3.6201663e-03,  1.2796778e-03,  4.0890765e-03,
#         3.2890588e-03,  3.0807797e-03,  1.9979298e-03, -1.1946845e-04,
#         2.8702940e-03,  4.8626680e-03, -2.6661153e-03,  8.9778932e-04,
#        -4.3168568e-04,  3.5303696e-03,  2.1694896e-04,  8.7484223e-04,
#        -2.7474156e-03,  2.3072974e-03, -4.0924000e-03,  3.6694556e-03,
#        -1.3320621e-03, -3.0234435e-03, -2.5829002e-03, -6.7849323e-04,
#         4.4032671e-03, -4.9507194e-03, -6.1436801e-04, -1.5792623e-03,
#        -1.2434268e-03, -1.0983588e-03,  1.4996656e-03, -3.4952483e-03,
#         4.6523707e-03,  3.9034693e-03, -4.6174503e-03, -5.3702452e-04,
#        -3.4897919e-03,  2.5301194e-03, -4.2174128e-03, -2.3708383e-03,
#        -9.7744912e-04, -1.7065967e-03, -3.3377951e-03,  7.5072236e-04,
#         3.3937241e-03,  3.8625572e-03, -1.7226865e-03,  5.1567581e-04,
#        -1.9285055e-03,  2.0000597e-03, -3.4114390e-03,  4.7271914e-04,
#        -2.4166233e-03,  4.5798719e-03, -2.6406355e-03, -9.7798940e-04,
#        -5.8665365e-04, -2.9146681e-03, -1.5723135e-03,  4.7215261e-03,
#         2.1700722e-03, -1.8198769e-04, -1.4113018e-03, -3.9183716e-03,
#         3.1917165e-03, -3.7289022e-03, -4.9690379e-06,  2.2584288e-03,
#        -4.7892290e-03,  3.4716236e-03,  5.8201712e-04, -1.1524011e-03,
#         1.1520652e-03, -2.2650061e-03, -3.4064935e-03, -4.3898900e-03,
#         2.6050124e-03, -4.1189080e-04,  4.4169971e-03,  2.2522782e-03,
#         4.6058926e-03,  4.4816905e-03, -2.9019178e-03,  3.8580929e-03,
#        -2.6810628e-03, -4.6606534e-03, -2.0499239e-03,  9.3182712e-04,
#         2.7559956e-03, -2.8712004e-03, -4.2591151e-03,  3.2236876e-03,
#        -2.9194662e-03, -3.0616710e-03, -1.3732996e-03, -7.9340482e-04,
#         1.6008539e-04,  3.2693732e-03,  2.2080629e-03,  4.6802708e-03],
#       dtype=float32)

# %%
avocado = model.wv['avocado']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-c341b60f5b96> in <module>
# ----> 1 avocado = model.wv['avocado']
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'avocado' not in vocabulary"

# %%
cheese = model.wv['cheese']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-5850543e4faa> in <module>
# ----> 1 cheese = model.wv['cheese']
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'cheese' not in vocabulary"

# %%
from gensim.models.word2vec import BrownCorpus

# %%
model = Word2Vec(BrownCorpus('/home/ubuntu/nltk_data/corpora/brown'))
# Out:
# 2020-04-28 21:00:01,760 : INFO : collecting all words and their counts
# 2020-04-28 21:00:01,761 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-28 21:00:02,004 : INFO : PROGRESS: at sentence #10000, processed 184896 words, keeping 21493 word types
# 2020-04-28 21:00:02,238 : INFO : PROGRESS: at sentence #20000, processed 361784 words, keeping 30751 word types
# 2020-04-28 21:00:02,465 : INFO : PROGRESS: at sentence #30000, processed 533189 words, keeping 38041 word types
# 2020-04-28 21:00:02,706 : INFO : PROGRESS: at sentence #40000, processed 713064 words, keeping 44354 word types
# 2020-04-28 21:00:02,932 : INFO : PROGRESS: at sentence #50000, processed 881301 words, keeping 50158 word types
# 2020-04-28 21:00:03,112 : INFO : collected 54294 word types from a corpus of 1008788 raw words and 57160 sentences
# 2020-04-28 21:00:03,112 : INFO : Loading a fresh vocabulary
# 2020-04-28 21:00:03,144 : INFO : effective_min_count=5 retains 15079 unique words (27% of original 54294, drops 39215)
# 2020-04-28 21:00:03,145 : INFO : effective_min_count=5 leaves 944942 word corpus (93% of original 1008788, drops 63846)
# 2020-04-28 21:00:03,183 : INFO : deleting the raw counts dictionary of 54294 items
# 2020-04-28 21:00:03,185 : INFO : sample=0.001 downsamples 41 most-common words
# 2020-04-28 21:00:03,185 : INFO : downsampling leaves estimated 713391 word corpus (75.5% of prior 944942)
# 2020-04-28 21:00:03,211 : INFO : estimated required memory for 15079 words and 100 dimensions: 19602700 bytes
# 2020-04-28 21:00:03,212 : INFO : resetting layer weights
# 2020-04-28 21:00:05,706 : INFO : training model with 3 workers on 15079 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-04-28 21:00:06,714 : INFO : EPOCH 1 - PROGRESS: at 59.73% examples, 428210 words/s, in_qsize 0, out_qsize 0
# 2020-04-28 21:00:07,350 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:00:07,352 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:00:07,363 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:00:07,364 : INFO : EPOCH - 1 : training on 1008788 raw words (713483 effective words) took 1.7s, 430889 effective words/s
# 2020-04-28 21:00:08,370 : INFO : EPOCH 2 - PROGRESS: at 56.93% examples, 407689 words/s, in_qsize 0, out_qsize 0
# 2020-04-28 21:00:09,037 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:00:09,039 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:00:09,051 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:00:09,052 : INFO : EPOCH - 2 : training on 1008788 raw words (713188 effective words) took 1.7s, 422899 effective words/s
# 2020-04-28 21:00:10,054 : INFO : EPOCH 3 - PROGRESS: at 58.83% examples, 423454 words/s, in_qsize 0, out_qsize 0
# 2020-04-28 21:00:10,716 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:00:10,717 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:00:10,729 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:00:10,729 : INFO : EPOCH - 3 : training on 1008788 raw words (713608 effective words) took 1.7s, 425720 effective words/s
# 2020-04-28 21:00:11,739 : INFO : EPOCH 4 - PROGRESS: at 61.67% examples, 441387 words/s, in_qsize 0, out_qsize 0
# 2020-04-28 21:00:12,337 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:00:12,339 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:00:12,350 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:00:12,350 : INFO : EPOCH - 4 : training on 1008788 raw words (713483 effective words) took 1.6s, 440579 effective words/s
# 2020-04-28 21:00:13,354 : INFO : EPOCH 5 - PROGRESS: at 56.93% examples, 409115 words/s, in_qsize 0, out_qsize 0
# 2020-04-28 21:00:14,044 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:00:14,046 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:00:14,056 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:00:14,057 : INFO : EPOCH - 5 : training on 1008788 raw words (713486 effective words) took 1.7s, 418479 effective words/s
# 2020-04-28 21:00:14,057 : INFO : training on a 5043940 raw words (3567248 effective words) took 8.4s, 427177 effective words/s

# %%
avocado = model.wv['avocado']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-c341b60f5b96> in <module>
# ----> 1 avocado = model.wv['avocado']
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'avocado' not in vocabulary"

# %%
avocado = model.wv['president']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d73726c27bfa> in <module>
# ----> 1 avocado = model.wv['president']
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'president' not in vocabulary"

# %%
avocado = model.wv['cheese']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5a0e8b37e04e> in <module>
# ----> 1 avocado = model.wv['cheese']
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'cheese' not in vocabulary"

# %%
model.wv

# %%
model.wv.vocab
# Out:
# {'image/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd396ded0>,
#  'intensification/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3cfc650>,
#  'is/be': <gensim.models.keyedvectors.Vocab at 0x7f3cd3832f50>,
#  'applied/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3832990>,
#  'under/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a410>,
#  'conditions/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a3d0>,
#  'of/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a350>,
#  'low/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a490>,
#  'incident/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a450>,
#  'light/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a310>,
#  'levels/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a5d0>,
#  'whenever/wr': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a610>,
#  'the/at': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a590>,
#  'integration/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a4d0>,
#  'time/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a510>,
#  'required/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a690>,
#  'by/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a6d0>,
#  'a/at': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a710>,
#  'or/cc': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a750>,
#  'recording/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a790>,
#  'instrument/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a7d0>,
#  'exceeds/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a810>,
#  'limits/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a850>,
#  'examples/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a890>,
#  'such/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a8d0>,
#  'situations/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a910>,
#  'are/be': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a950>,
#  'aerial/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a990>,
#  'night/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384a9d0>,
#  'reconnaissance/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384aa10>,
#  'recording/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384aa50>,
#  'radioactive/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384aa90>,
#  'in/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd384aad0>,
#  'live/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ab10>,
#  'body/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ab50>,
#  'tissues/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ab90>,
#  'special/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384abd0>,
#  'medical/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ac10>,
#  'industrial/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ac50>,
#  'applications/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ac90>,
#  'track/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384acd0>,
#  'high/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ad10>,
#  'energy/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ad50>,
#  'particles/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ad90>,
#  'etc./rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd384add0>,
#  'may/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ae10>,
#  'be/be': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ae50>,
#  'achieved/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd384ae90>,
#  'several/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd384aed0>,
#  'methods/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd384af10>,
#  'some/dt': <gensim.models.keyedvectors.Vocab at 0x7f3cd384af50>,
#  'these/dt': <gensim.models.keyedvectors.Vocab at 0x7f3cd384af90>,
#  'listed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd384afd0>,
#  'below/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3826150>,
#  'a/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd3826050>,
#  'single/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd3826090>,
#  'stages/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38260d0>,
#  'coupling/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3826110>,
#  'lens/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35aea90>,
#  'systems/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35ae410>,
#  'b/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35a51d0>,
#  'secondary/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35a5150>,
#  'emission/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35a5110>,
#  'intensifier/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35a5450>,
#  'c/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35a5bd0>,
#  'based/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35a56d0>,
#  'upon/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3d50>,
#  'principle/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b37d0>,
#  'd/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b35d0>,
#  'transmission/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3d10>,
#  'electron/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3850>,
#  'multiplication/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b38d0>,
#  'intensifiers/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3c90>,
#  'tubes/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3210>,
#  'e/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3110>,
#  'enclosed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3150>,
#  'one/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3490>,
#  'common/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3950>,
#  'envelope/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3cd0>,
#  'rather/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3f10>,
#  'inefficient/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b32d0>,
#  'as/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3d90>,
#  'limit/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3e50>,
#  'obtainable/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3dd0>,
#  'gain/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3e10>,
#  'quite/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3610>,
#  'severely/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3790>,
#  'capable/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3710>,
#  'achieving/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3050>,
#  'values/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3410>,
#  'they/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3690>,
#  'suffer/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3810>,
#  'however/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3e90>,
#  'from/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3190>,
#  'an/at': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3310>,
#  'resolution/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3b10>,
#  'appear/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b33d0>,
#  'to/to': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3090>,
#  'hold/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3fd0>,
#  'promise/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b34d0>,
#  'as/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3250>,
#  'far/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b39d0>,
#  'concerned/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b3990>,
#  'unavoidable/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8f90>,
#  'cycle/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8fd0>,
#  'effective/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8b10>,
#  'have/hv': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8490>,
#  'been/be': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8f50>,
#  'constructed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8e50>,
#  'showing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8450>,
#  'and/cc': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8050>,
#  'electrostatic/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8110>,
#  'focus/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b80d0>,
#  'important/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8ed0>,
#  'for/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8f10>,
#  'many/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8150>,
#  'has/hv': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8190>,
#  'realized/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b81d0>,
#  'devices/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8210>,
#  'limitations/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8250>,
#  'with/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8510>,
#  'might/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8090>,
#  'anticipated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b84d0>,
#  'due/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8b90>,
#  'to/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8bd0>,
#  'chromatic/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8790>,
#  'aberrations/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8750>,
#  'furthermore/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b87d0>,
#  'thin/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8c90>,
#  'film/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8cd0>,
#  'natural/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8d10>,
#  'diameter/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8d50>,
#  'limitation/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8d90>,
#  'wherever/wr': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8b50>,
#  'support/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8810>,
#  'cannot/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8850>,
#  'tolerated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b86d0>,
#  'differ/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b88d0>,
#  'both/ab': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8310>,
#  'choice/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8890>,
#  'optical/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8c50>,
#  'system/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8c10>,
#  'design/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b82d0>,
#  'members/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8290>,
#  'either/cc': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8350>,
#  'magnetic/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8390>,
#  'magnification/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b83d0>,
#  'smaller/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8550>,
#  'equal/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8e90>,
#  'larger/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8e10>,
#  'than/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8410>,
#  'unity/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8590>,
#  'suffers/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b85d0>,
#  'generally/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8610>,
#  'plane/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8650>,
#  'curvature/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8690>,
#  'leading/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8910>,
#  'peripheral/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8950>,
#  'region/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8990>,
#  'if/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b89d0>,
#  'flat/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8a10>,
#  'viewing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8a50>,
#  'screen/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8a90>,
#  'coupler/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8710>,
#  'utilized/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b8dd0>,
#  'while/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5650>,
#  'requires/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5410>,
#  'accurate/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5a50>,
#  'adjustment/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5290>,
#  'which/wd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5b90>,
#  'heavy/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5210>,
#  'bulky/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5250>,
#  'it/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5310>,
#  'will/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b57d0>,
#  'discussed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5fd0>,
#  'later/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5f50>,
#  'can/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5dd0>,
#  'improved/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5910>,
#  'on/rp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5810>,
#  'utilizing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b53d0>,
#  'curved/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b5b10>,
#  'fiber/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b2c90>,
#  'should/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b2110>,
#  'noted/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b2610>,
#  'that/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b2f50>,
#  'similar/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b23d0>,
#  'felt/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b2650>,
#  'stage/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4d10>,
#  'gain/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4510>,
#  'considerable/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4650>,
#  'importance/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b48d0>,
#  'future/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4750>,
#  'therefore/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4a10>,
#  'we/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4a90>,
#  'shall/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4610>,
#  'consider/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4190>,
#  'this/dt': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4290>,
#  'paper/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4690>,
#  'theoretical/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4210>,
#  'capabilities/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4a50>,
#  'luminous/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4d50>,
#  'efficiency/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4cd0>,
#  'finally/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b47d0>,
#  'composite/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4850>,
#  'tube/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b40d0>,
#  'computed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4b10>,
#  'shown/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4c10>,
#  'theoretically/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4310>,
#  'such/ab': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4890>,
#  'contact/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b44d0>,
#  'photography/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4c90>,
#  'permits/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4490>,
#  'utilization/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4450>,
#  'extremely/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4090>,
#  'effect/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4050>,
#  'device/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4e50>,
#  'quantum/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b43d0>,
#  'noise/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4790>,
#  'associated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4e90>,
#  'such/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b46d0>,
#  'input/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4710>,
#  'described/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4390>,
#  'after/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4810>,
#  'considerations/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4110>,
#  'details/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b45d0>,
#  'x-ray/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b49d0>,
#  'measured/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4f90>,
#  'performance/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4bd0>,
#  'characteristics/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4950>,
#  'experimental/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4f50>,
#  'conclusion/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4910>,
#  'reached/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4ed0>,
#  'represent/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4b50>,
#  'sensible/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4250>,
#  'practical/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4990>,
#  'approach/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b4ad0>,
#  'basic/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833050>,
#  'forms/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833090>,
#  'basis/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38330d0>,
#  'discussion/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833110>,
#  'now/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833150>,
#  'see/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833190>,
#  'fig./nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38331d0>,
#  'on/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833210>,
#  'focusing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833250>,
#  'action/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833290>,
#  'spherical/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd38332d0>,
#  'cathode/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833310>,
#  'anode/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833350>,
#  'surfaces/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833390>,
#  'inner/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd38333d0>,
#  'sphere/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833410>,
#  'elongated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833450>,
#  'into/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833490>,
#  'cup/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38334d0>,
#  'phosphor/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833510>,
#  'circular/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833550>,
#  'segment/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833590>,
#  'focused/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd38335d0>,
#  'positive/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833610>,
#  'two/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833650>,
#  'pass/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833690>,
#  'through/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd38336d0>,
#  'negative/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833710>,
#  'formed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833750>,
#  'aperture/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833790>,
#  'cylindrical/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd38337d0>,
#  'electrode/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833810>,
#  'part/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833850>,
#  'varying/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833890>,
#  'potential/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38338d0>,
#  'm/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833910>,
#  'photocathode/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833950>,
#  'configuration/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833990>,
#  'seen/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd38339d0>,
#  'property/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833a10>,
#  'alleviate/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833a50>,
#  'losses/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833a90>,
#  'resulting/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833ad0>,
#  'member/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833b10>,
#  'same/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833b50>,
#  'reason/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833b90>,
#  'output/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833bd0>,
#  'plate/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833c10>,
#  'its/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833c50>,
#  'exposed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833c90>,
#  'side/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833cd0>,
#  'permitting/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833d10>,
#  'permanent/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833d50>,
#  'record/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833d90>,
#  'desired/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833dd0>,
#  'properties/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833e10>,
#  'comprise/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833e50>,
#  'indeed/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833e90>,
#  'main/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833ed0>,
#  'advantage/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833f10>,
#  'second/od': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833f50>,
#  'deposited/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833f90>,
#  's/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3833fd0>,
#  'p/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841050>,
#  'v/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841090>,
#  'individual/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd38410d0>,
#  'distinguished/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841110>,
#  'means/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841150>,
#  '1/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841190>,
#  '2/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd38411d0>,
#  'text/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841210>,
#  'where/wr': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841250>,
#  'assumed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841290>,
#  'flux/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38412d0>,
#  'af/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841310>,
#  'first/od': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841350>,
#  'approximation/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841390>,
#  'given/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd38413d0>,
#  'product/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841410>,
#  'sensitivity/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841450>,
#  'conversion/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841490>,
#  'general/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd38414d0>,
#  'function/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841510>,
#  'current/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841550>,
#  'density/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841590>,
#  'but/cc': <gensim.models.keyedvectors.Vocab at 0x7f3cd38415d0>,
#  'here/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841610>,
#  'constant/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841650>,
#  'depends/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841690>,
#  'maximum/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd38416d0>,
#  'radiant/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841710>,
#  'spectral/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841750>,
#  'distribution/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841790>,
#  'relation/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38417d0>,
#  'standard/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841810>,
#  'visibility/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841850>,
#  'falls/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841890>,
#  'beyond/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd38418d0>,
#  'visible/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841910>,
#  'range/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841950>,
#  'expected/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841990>,
#  'since/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd38419d0>,
#  'cases/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841a10>,
#  'considered/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841a50>,
#  'plates/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841a90>,
#  'four/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841ad0>,
#  'factors/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841b10>,
#  'numerical/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841b50>,
#  'end/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841b90>,
#  'reflection/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841bd0>,
#  'r/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841c10>,
#  'internal/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841c50>,
#  'packing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841c90>,
#  'fibers/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841cd0>,
#  'angle/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841d10>,
#  'medium/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841d50>,
#  'index/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841d90>,
#  'settled/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841dd0>,
#  'used/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841e10>,
#  'substrate/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841e50>,
#  'surface/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841e90>,
#  'hence/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841ed0>,
#  'close/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841f10>,
#  'condition/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841f50>,
#  'satisfied/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841f90>,
#  'e.g./rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3841fd0>,
#  'equivalent/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853050>,
#  'glass/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853090>,
#  'combinations/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38530d0>,
#  'sufficiently/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853110>,
#  'good/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853150>,
#  'determining/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853190>,
#  'r/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38531d0>,
#  'obtained/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853210>,
#  'independent/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853250>,
#  'formula/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853290>,
#  'air/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38532d0>,
#  'assuming/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853310>,
#  'obtain/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853350>,
#  'percent/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853390>,
#  'value/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38533d0>,
#  'reduced/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853410>,
#  'very/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853450>,
#  'layer/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853490>,
#  '1.5/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd38534d0>,
#  'factor/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853510>,
#  'lies/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853550>,
#  'around/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853590>,
#  'at/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd38535d0>,
#  'about/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853610>,
#  '0.5/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853650>,
#  'multiple/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853690>,
#  'coatings/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38536d0>,
#  'reduce/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853710>,
#  'even/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853750>,
#  'further/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853790>,
#  'due/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd38537d0>,
#  'absorption/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853810>,
#  'small/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853850>,
#  'finite/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853890>,
#  'suffered/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd38538d0>,
#  'numerous/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853910>,
#  'reflections/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853950>,
#  'prescribed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853990>,
#  'cross-section/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd38539d0>,
#  'minute/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853a10>,
#  'depend/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853a50>,
#  'length/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853a90>,
#  'mean/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853ad0>,
#  'loss/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853b10>,
#  'per/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853b50>,
#  'last/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853b90>,
#  'least/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853bd0>,
#  'angular/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853c10>,
#  'explicit/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853c50>,
#  'expressions/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853c90>,
#  'integral/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853cd0>,
#  'averages/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853d10>,
#  'literature/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853d50>,
#  'lacking/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853d90>,
#  'reliable/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853dd0>,
#  'data/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853e10>,
#  'variables/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853e50>,
#  'relying/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853e90>,
#  '20/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853ed0>,
#  'long/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853f10>,
#  '5/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853f50>,
#  '-/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853f90>,
#  '10/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3853fd0>,
#  'relatively/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9050>,
#  'probably/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9090>,
#  'increasing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b90d0>,
#  'number/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9110>,
#  'considering/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9150>,
#  'inches/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9190>,
#  'their/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b91d0>,
#  'average/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9210>,
#  'thickness/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9250>,
#  'kept/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9290>,
#  'below/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b92d0>,
#  'inch/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9310>,
#  '15/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9350>,
#  'did/do': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9390>,
#  'receive/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b93d0>,
#  'much/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9410>,
#  'attention/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9450>,
#  'until/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9490>,
#  'recently/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b94d0>,
#  'closely/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9510>,
#  'packed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9550>,
#  'array/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9590>,
#  'ratio/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b95d0>,
#  'area/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9610>,
#  'circle/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9650>,
#  'that/dt': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9690>,
#  'technically/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b96d0>,
#  'feasible/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9710>,
#  '100/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9750>,
#  'thus/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9790>,
#  'approximately/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b97d0>,
#  '50/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9810>,
#  'each/dt': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9850>,
#  'must/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9890>,
#  'remembered/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b98d0>,
#  'replace/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9910>,
#  'window/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9950>,
#  'membrane/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9990>,
#  'addition/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b99d0>,
#  'neglecting/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9a10>,
#  'would/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9a50>,
#  '6/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9a90>,
#  '8/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9ad0>,
#  'combined/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9b10>,
#  'elements/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9b50>,
#  'replaced/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9b90>,
#  'six/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9bd0>,
#  'times/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9c10>,
#  'less/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9c50>,
#  'coupled/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9c90>,
#  'including/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9cd0>,
#  'brightness/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9d10>,
#  'overall/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9d50>,
#  'double/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9d90>,
#  'obvious/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9dd0>,
#  'careful/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9e10>,
#  'e/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9e50>,
#  'case/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9e90>,
#  'consideration/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9ed0>,
#  'govern/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9f10>,
#  'matching/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9f50>,
#  'ultimate/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9f90>,
#  'photographic/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b9fd0>,
#  'evaluated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6050>,
#  'types/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6090>,
#  'three/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b60d0>,
#  'distributions/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6110>,
#  'so-called/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6150>,
#  'j./np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6190>,
#  'johnson/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b61d0>,
#  'units/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6210>,
#  'table/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6250>,
#  'inherent/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6290>,
#  'well/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b62d0>,
#  'stated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6310>,
#  'previously/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6350>,
#  'yields/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6390>,
#  'lower/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b63d0>,
#  'chosen/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6410>,
#  'voltage/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6450>,
#  'reduces/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6490>,
#  'increases/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b64d0>,
#  'was/be': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6510>,
#  'calculated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6550>,
#  '16/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6590>,
#  'possible/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b65d0>,
#  'screens/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6610>,
#  'interest/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6650>,
#  'because/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6690>,
#  'corresponds/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b66d0>,
#  'roughly/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6710>,
#  'conventional/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6750>,
#  'following/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6790>,
#  'specifications/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b67d0>,
#  'were/be': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6810>,
#  'lists/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6850>,
#  'according/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6890>,
#  'possibility/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b68d0>,
#  'space/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6910>,
#  'charge/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6950>,
#  'elementary/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6990>,
#  'bundles/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b69d0>,
#  'pointed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6a10>,
#  'out/rp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6a50>,
#  'influence/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6a90>,
#  'only/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6ad0>,
#  'final/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6b10>,
#  'influences/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6b50>,
#  'also/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6b90>,
#  'decrease/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6bd0>,
#  'increased/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6c10>,
#  'type/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6c50>,
#  'tested/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6c90>,
#  'applying/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6cd0>,
#  '70/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6d10>,
#  '80/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6d50>,
#  'appears/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6d90>,
#  'decreases/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6dd0>,
#  'increasingly/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6e10>,
#  'aggregate/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6e50>,
#  'decreasing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6e90>,
#  'impaired/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6ed0>,
#  'normally/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6f10>,
#  'aluminum/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6f50>,
#  'mirror/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6f90>,
#  'effects/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35b6fd0>,
#  'determine/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb050>,
#  'limit/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb090>,
#  'generated/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb0d0>,
#  'within/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb110>,
#  'impact/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb150>,
#  'excess/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb190>,
#  '30/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb1d0>,
#  'limiting/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb210>,
#  '60/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb250>,
#  'aj/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb290>,
#  'further/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb2d0>,
#  'assume/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb310>,
#  'going/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb350>,
#  'downstairs/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb390>,
#  'tray/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb3d0>,
#  'winston/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb410>,
#  'wished/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb450>,
#  'he/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb490>,
#  'could/md': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb4d0>,
#  'in/rp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb510>,
#  'miss/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb550>,
#  'ada/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb590>,
#  'knew/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb5d0>,
#  'better/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb610>,
#  'do/do': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb650>,
#  'what/wd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb690>,
#  'she/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb6d0>,
#  'said/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb710>,
#  'when/wr': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb750>,
#  'had/hv': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb790>,
#  'look/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb7d0>,
#  'there/ex': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb810>,
#  "wasn't/be": <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb850>,
#  'right/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb890>,
#  'make/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb8d0>,
#  'person/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb910>,
#  'happy/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb950>,
#  'like/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb990>,
#  'came/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bb9d0>,
#  'kitchen/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bba10>,
#  'asked/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bba50>,
#  'know/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bba90>,
#  "don't/do": <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbad0>,
#  'keep/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbb10>,
#  'peanut/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbb50>,
#  'butter/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbb90>,
#  'sandwich/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbbd0>,
#  'you/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbc10>,
#  'house/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbc50>,
#  'always/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbc90>,
#  'told/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbcd0>,
#  'her/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbd10>,
#  'why/wr': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbd50>,
#  "she'd/pp": <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbd90>,
#  'cry/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbdd0>,
#  'i/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbe10>,
#  'just/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbe50>,
#  'saw/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbe90>,
#  'eating/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbed0>,
#  'out/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbf10>,
#  'jar/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbf50>,
#  'how/wr': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbf90>,
#  'figure/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bbfd0>,
#  'leona/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd050>,
#  'his/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd090>,
#  'little/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd0d0>,
#  'young/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd110>,
#  'wife/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd150>,
#  'reading/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd190>,
#  'morning/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd1d0>,
#  'legs/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd210>,
#  'hung/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd250>,
#  'down/rp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd290>,
#  'sat/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd2d0>,
#  'stool/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd310>,
#  'gently/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd350>,
#  "what's/wd": <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd390>,
#  'dishes/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd3d0>,
#  'doing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd410>,
#  'washed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd450>,
#  'enormous/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd490>,
#  'held/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd4d0>,
#  'mr./np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd510>,
#  "jack's/np": <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd550>,
#  'fried/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd590>,
#  'eggs/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd5d0>,
#  'five/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd610>,
#  'strips/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd650>,
#  'bacon/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd690>,
#  'still/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd6d0>,
#  'stacked/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd710>,
#  'sink/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd750>,
#  'leave/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd790>,
#  'me/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd7d0>,
#  'alone/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd810>,
#  "can't/md": <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd850>,
#  "i'm/pp": <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd890>,
#  'busy/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd8d0>,
#  'looked/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd910>,
#  'him/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd950>,
#  'over/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd990>,
#  'corner/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bd9d0>,
#  'moving/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bda10>,
#  'day/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bda50>,
#  'reminded/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bda90>,
#  'bet/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdad0>,
#  'left/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdb10>,
#  'things/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdb50>,
#  'every/at': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdb90>,
#  'way/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdbd0>,
#  'upstairs/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdc10>,
#  'your/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdc50>,
#  'clothes/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdc90>,
#  'all/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdcd0>,
#  'floor/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdd10>,
#  'bed/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdd50>,
#  'made/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdd90>,
#  'eye/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bddd0>,
#  'fastened/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bde10>,
#  'leg/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bde50>,
#  'bending/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bde90>,
#  'touched/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bded0>,
#  'knee/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdf10>,
#  'catch/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdf50>,
#  'more/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdf90>,
#  'without/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35bdfd0>,
#  'stockings/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0050>,
#  'away/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0090>,
#  'old/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c00d0>,
#  'man/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0110>,
#  'alley/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0150>,
#  'manners/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0190>,
#  'pink/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c01d0>,
#  'then/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0210>,
#  'spread/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0250>,
#  'list/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0290>,
#  'counter/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c02d0>,
#  'behind/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0310>,
#  'printed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0350>,
#  'top/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0390>,
#  'fine/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c03d0>,
#  'hand/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0410>,
#  'took/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0450>,
#  'pencil/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0490>,
#  'admired/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c04d0>,
#  'point/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0510>,
#  'wrote/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0550>,
#  'slowly/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0590>,
#  'heavily/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c05d0>,
#  'stand/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0610>,
#  'sighing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0650>,
#  'dropped/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c0690>,
# ...
#  "that's/dt": <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2610>,
#  'waiting/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2650>,
#  'began/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2690>,
#  'almost/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c26d0>,
#  'glad/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2710>,
#  'cut/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2750>,
#  'off/rp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2790>,
#  'too/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c27d0>,
#  'wash/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2810>,
#  'hands/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2850>,
#  'truth/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2890>,
#  'hardly/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c28d0>,
#  'believed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2910>,
#  'himself/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2950>,
#  'more/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2990>,
#  'although/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c29d0>,
#  'seemed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2a10>,
#  'begin/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2a50>,
#  'no/at': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2a90>,
#  'couple/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2ad0>,
#  'afford/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2b10>,
#  'work/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2b50>,
#  'hanging/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2b90>,
#  'job/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2bd0>,
#  'doubted/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2c10>,
#  'whether/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2c50>,
#  'heard/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2c90>,
#  'running/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2cd0>,
#  'water/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2d10>,
#  'while/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2d50>,
#  'knees/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2d90>,
#  'watching/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2dd0>,
#  'bend/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2e10>,
#  'back/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2e50>,
#  'gathered/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2e90>,
#  'comb/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2ed0>,
#  'bottle/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2f10>,
#  'take/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2f50>,
#  'pack/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2f90>,
#  'sad/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c2fd0>,
#  'days/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4050>,
#  'never/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4090>,
#  'sure/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c40d0>,
#  'something/pn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4110>,
#  'quick/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4150>,
#  'bent/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4190>,
#  'straight/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c41d0>,
#  'jack/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4210>,
#  'hall/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4250>,
#  'hurried/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4290>,
#  'swinging/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c42d0>,
#  'door/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4310>,
#  "i've/pp": <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4350>,
#  'bursting/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4390>,
#  'my/pp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c43d0>,
#  'lungs/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4410>,
#  'complained/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4450>,
#  'standing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4490>,
#  'front/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c44d0>,
#  'tie/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4510>,
#  'gray/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4550>,
#  'tweed/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4590>,
#  'overcoat/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c45d0>,
#  'city/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4610>,
#  'hat/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4650>,
#  'brief/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4690>,
#  'lay/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c46d0>,
#  'bench/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4710>,
#  "you've/pp": <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4750>,
#  'coat/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4790>,
#  'looks/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c47d0>,
#  'rag/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4810>,
#  'heap/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4850>,
#  'few/ap': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4890>,
#  'blades/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c48d0>,
#  'shoulder/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4910>,
#  'closet/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4950>,
#  'work/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4990>,
#  'gave/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c49d0>,
#  'real/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4a10>,
#  'brushed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4a50>,
#  'shoulders/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4a90>,
#  'collar/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4ad0>,
#  'firm/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4b10>,
#  'strokes/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4b50>,
#  'hey/uh': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4b90>,
#  'cried/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4bd0>,
#  'brush/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4c10>,
#  'eyes/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4c50>,
#  'apologized/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4c90>,
#  'quickly/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4cd0>,
#  'set/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4d10>,
#  'look/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4d50>,
#  'who/wp': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4d90>,
#  'pulling/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4dd0>,
#  'gloves/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4e10>,
#  'enjoyed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4e50>,
#  'seeing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4e90>,
#  'start/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4ed0>,
#  'style/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4f10>,
#  'town/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4f50>,
#  'nothing/pn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4f90>,
#  'enough/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c4fd0>,
#  'cursed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6050>,
#  'once/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6090>,
#  'leaving/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c60d0>,
#  'home/nr': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6110>,
#  "wouldn't/md": <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6150>,
#  'even/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6190>,
#  'supper/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c61d0>,
#  'wandered/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6210>,
#  'yard/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6250>,
#  'pair/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6290>,
#  'sweaty/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c62d0>,
#  'smoking/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6310>,
#  'jackets/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6350>,
#  'blue/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6390>,
#  'bought/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c63d0>,
#  'giving/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6410>,
#  'set/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6450>,
#  'those/dt': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6490>,
#  'hurry/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c64d0>,
#  'down/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6510>,
#  'drive/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6550>,
#  'car/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6590>,
#  'handsome/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c65d0>,
#  'fine-looking/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6610>,
#  'proud/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6650>,
#  'after/cs': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6690>,
#  'drove/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c66d0>,
#  'looking/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6710>,
#  'noticed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6750>,
#  'speck/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6790>,
#  'dirt/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c67d0>,
#  'finger/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6810>,
#  'wrinkled/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6850>,
#  'thick/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6890>,
#  'nail/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c68d0>,
#  'knife/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6910>,
#  'pry/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6950>,
#  'open/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6990>,
#  'move/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c69d0>,
#  'ten/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6a10>,
#  'off/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6a50>,
#  'life/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6a90>,
#  'let/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6ad0>,
#  'brass/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6b10>,
#  'handle/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6b50>,
#  'shone/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6b90>,
#  'reward/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6bd0>,
#  'dust/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6c10>,
#  'china/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6c50>,
#  'flowers/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6c90>,
#  'drops/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6cd0>,
#  'blind/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6d10>,
#  'fingers/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6d50>,
#  'like/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6d90>,
#  'rags/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6dd0>,
#  'spent/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6e10>,
#  'keeping/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6e50>,
#  'ago/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6e90>,
#  'interviewed/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6ed0>,
#  'blooming/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6f10>,
#  'along/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6f50>,
#  'walked/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6f90>,
#  'bus/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c6fd0>,
#  'almost/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9050>,
#  'singing/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9090>,
#  'straw/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c90d0>,
#  'talked/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9110>,
#  'right/ql': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9150>,
#  'there/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9190>,
#  'hot/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c91d0>,
#  'sun/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9210>,
#  'face/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9250>,
#  'feel/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9290>,
#  'ashamed/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c92d0>,
#  'surprised/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9310>,
#  'liked/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9350>,
#  'fresh/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9390>,
#  'neat/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c93d0>,
#  'cotton/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9410>,
#  'dress/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9450>,
#  'yellow/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9490>,
#  'dignity/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c94d0>,
#  'even/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9510>,
#  'tan/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9550>,
#  'since/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9590>,
#  'planted/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c95d0>,
#  'hill/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9610>,
#  'flock/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9650>,
#  'front/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9690>,
#  'gate/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c96d0>,
#  'coming/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9710>,
#  'porch/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9750>,
#  'steps/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9790>,
#  'week/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c97d0>,
#  'early/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9810>,
#  'may/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9850>,
#  'party/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9890>,
#  'japanese/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c98d0>,
#  'wet/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9910>,
#  'trees/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9950>,
#  'buds/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9990>,
#  'marching/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c99d0>,
#  'parade/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9a10>,
#  'dug/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9a50>,
#  'hole/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9a90>,
#  'bulb/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9ad0>,
#  'tree/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9b10>,
#  'tag/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9b50>,
#  'writing/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9b90>,
#  'somehow/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9bd0>,
#  "didn't/do": <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9c10>,
#  'boxes/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9c50>,
#  'living/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9c90>,
#  'thousand/cd': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9cd0>,
#  "couldn't/md": <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9d10>,
#  'help/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9d50>,
#  'thinking/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9d90>,
#  "we're/pp": <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9dd0>,
#  'getting/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9e10>,
#  'horns/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9e50>,
#  'lists/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9e90>,
#  'garden/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9ed0>,
#  'basket/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9f10>,
#  'brought/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9f50>,
#  'beside/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9f90>,
#  'easter/np': <gensim.models.keyedvectors.Vocab at 0x7f3cd35c9fd0>,
#  'suit/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb050>,
#  'binding/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb090>,
#  'halfway/rb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb0d0>,
#  'across/in': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb110>,
#  'smelled/vb': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb150>,
#  'perfume/nn': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb190>,
#  'sweet/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb1d0>,
#  'strong/jj': <gensim.models.keyedvectors.Vocab at 0x7f3cd35cb210>,
#  ...}

# %%
model.wv['avocado/nn']
# Out:
# array([ 0.13542426,  0.08641184, -0.06718861, -0.06150314,  0.04078102,
#        -0.01311649,  0.02429487,  0.05043231,  0.0688144 ,  0.05826308,
#        -0.08768259,  0.06050111,  0.01696055, -0.07378364, -0.08366   ,
#        -0.04544665,  0.00342775, -0.01289376,  0.03894362, -0.0227945 ,
#         0.03141955,  0.18336345, -0.01032996, -0.03418918, -0.03222478,
#         0.05456274,  0.20482992,  0.11831625,  0.0024343 , -0.04893686,
#         0.03770311, -0.0399111 , -0.15655242,  0.01034668, -0.06910104,
#        -0.06439083, -0.09890756,  0.01149493, -0.02454964,  0.04047146,
#         0.04330104,  0.09573743, -0.02907959,  0.00096501,  0.10755651,
#         0.05820831,  0.01706162, -0.03298414,  0.02794273,  0.05917836,
#        -0.01910414, -0.06989597,  0.04259958, -0.02260439,  0.09474701,
#         0.08870851, -0.08878886,  0.02434646,  0.05695599, -0.03341379,
#        -0.0671249 ,  0.029426  ,  0.05028586, -0.00200809,  0.10357421,
#        -0.07066309,  0.07806551,  0.15439007, -0.02634114, -0.00834144,
#        -0.10757085,  0.01156261, -0.06251957, -0.05410023, -0.04346665,
#         0.05413099, -0.08140296,  0.00238806, -0.0961572 ,  0.01699571,
#        -0.03643536, -0.13934498,  0.03162064,  0.04768552, -0.0434703 ,
#         0.00463364,  0.07250846, -0.02370872,  0.03334152,  0.03181191,
#        -0.07126165,  0.14493777,  0.06899717, -0.08784335, -0.0201662 ,
#        -0.00776169,  0.12795702,  0.03204667, -0.10366127,  0.12726781],
#       dtype=float32)

# %%
model.wv.similar_by_word('avocado/nn')
# Out:
# 2020-04-28 21:04:33,722 : INFO : precomputing L2-norms of word weight vectors
# [('encouragement/nn', 0.9326245784759521),
#  ('wise/jj', 0.9317049384117126),
#  ('mess/nn', 0.9286695718765259),
#  ('attempt/nn', 0.9277729392051697),
#  ('weaken/vb', 0.926093578338623),
#  ('guys/nn', 0.925919234752655),
#  ('enjoy/vb', 0.9254236817359924),
#  ('practice/vb', 0.9252655506134033),
#  ('repel/vb', 0.9240432977676392),
#  ('grant/vb', 0.9239420890808105)]

# %%
model.wv.similar_by_word('cheese/nn')
# Out:
# [('lime/nn', 0.9784870743751526),
#  ('editors/nn', 0.9694792032241821),
#  ('vivid/jj', 0.968917727470398),
#  ('jokes/nn', 0.9682754278182983),
#  ('grapes/nn', 0.9673639535903931),
#  ('uneven/jj', 0.9670487642288208),
#  ('corn/nn', 0.9668615460395813),
#  ('carpenter/nn', 0.9665806293487549),
#  ('loose/jj', 0.9654962420463562),
#  ('brutal/jj', 0.9653011560440063)]

# %% [markdown]
# ## TODO
# * Write generator that produces sentences by
#  * iterating over a json file
#  * iterating over a directory of json files

# %%
DATA_HOME = '/home/ubuntu/XCS224U-Project/data/raw_web_joined'

# %%
from os import path, listdir

# %%
f1 = path.join(DATA_HOME, '703_00156_2019-11-13_2_2641647_joined.json')

# %%
import json

# %%
from ir import normalize_word

# %%
class ReceiptIter:
    def __init__(self):
        self.data_path = '/home/ubuntu/XCS224U-Project/data/raw_web_joined'
        
    def __iter__(self):
        for fname in listdir(self.data_path):
            file_path = path.join(self.data_path, fname)
            with open(file_path, 'r') as f:                
                receipts = json.load(f)
                for receipt in receipts:
                    web_sent = [normalize_word(w) for w in receipt['web'].lower().split()]
                    yield web_sent
                    raw_sent = [normalize_word(w) for w in receipt['raw'].lower().split()]
                    yield raw_sent

# %%
ri = ReceiptIter()

# %%
sents = [sent for sent in ri]

# %%
sents[:10]
# Out:
# [['bobs', 'blue', 'cheese', 'dressing'],
#  ['bobs', 'drsng'],
#  ['carrot'],
#  ['carrots', 'clip', 'top'],
#  ['challenge', 'unsalted', 'butter'],
#  ['challenge', 'butter'],
#  ['cilantro'],
#  ['cilantro'],
#  ['egglands', 'best', 'grade', 'a', 'large', 'eggs'],
#  ['egglands', 'best', 'eggs']]

# %%
len(sents)
# Out:
# 1422

# %%
model = Word2Vec(ReceiptIter())
# Out:
# 2020-04-28 21:59:20,386 : INFO : collecting all words and their counts
# 2020-04-28 21:59:20,387 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-28 21:59:20,400 : INFO : collected 1024 word types from a corpus of 6082 raw words and 1422 sentences
# 2020-04-28 21:59:20,400 : INFO : Loading a fresh vocabulary
# 2020-04-28 21:59:20,401 : INFO : effective_min_count=5 retains 262 unique words (25% of original 1024, drops 762)
# 2020-04-28 21:59:20,401 : INFO : effective_min_count=5 leaves 4724 word corpus (77% of original 6082, drops 1358)
# 2020-04-28 21:59:20,403 : INFO : deleting the raw counts dictionary of 1024 items
# 2020-04-28 21:59:20,403 : INFO : sample=0.001 downsamples 107 most-common words
# 2020-04-28 21:59:20,403 : INFO : downsampling leaves estimated 2937 word corpus (62.2% of prior 4724)
# 2020-04-28 21:59:20,404 : INFO : estimated required memory for 262 words and 100 dimensions: 340600 bytes
# 2020-04-28 21:59:20,404 : INFO : resetting layer weights
# 2020-04-28 21:59:20,453 : INFO : training model with 3 workers on 262 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-04-28 21:59:20,468 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:59:20,469 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:59:20,472 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:59:20,472 : INFO : EPOCH - 1 : training on 6082 raw words (2881 effective words) took 0.0s, 162656 effective words/s
# 2020-04-28 21:59:20,487 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:59:20,487 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:59:20,491 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:59:20,491 : INFO : EPOCH - 2 : training on 6082 raw words (2924 effective words) took 0.0s, 163244 effective words/s
# 2020-04-28 21:59:20,506 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:59:20,507 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:59:20,510 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:59:20,510 : INFO : EPOCH - 3 : training on 6082 raw words (2927 effective words) took 0.0s, 163825 effective words/s
# 2020-04-28 21:59:20,524 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:59:20,525 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:59:20,529 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:59:20,529 : INFO : EPOCH - 4 : training on 6082 raw words (2899 effective words) took 0.0s, 162466 effective words/s
# 2020-04-28 21:59:20,544 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 21:59:20,544 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 21:59:20,547 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 21:59:20,548 : INFO : EPOCH - 5 : training on 6082 raw words (2930 effective words) took 0.0s, 166468 effective words/s
# 2020-04-28 21:59:20,548 : INFO : training on a 30410 raw words (14561 effective words) took 0.1s, 153981 effective words/s
# 2020-04-28 21:59:20,548 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model.wv.vocab
# Out:
# {'blue': <gensim.models.keyedvectors.Vocab at 0x7f3cd35fbcd0>,
#  'cheese': <gensim.models.keyedvectors.Vocab at 0x7f3cd37002d0>,
#  'dressing': <gensim.models.keyedvectors.Vocab at 0x7f3cd39b5990>,
#  'unsalted': <gensim.models.keyedvectors.Vocab at 0x7f3cd372ae50>,
#  'butter': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d7b390>,
#  'egglands': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d7bc90>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b63d0>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b6f50>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d7b4d0>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d7b610>,
#  'eggs': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b6a10>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b6690>,
#  'gourmet': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b67d0>,
#  'crispy': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b60d0>,
#  'jalapenos': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b66d0>,
#  'fgor': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b6a50>,
#  'jalapen': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b6c50>,
#  'garlic': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b6a90>,
#  'pepper': <gensim.models.keyedvectors.Vocab at 0x7f3cd37b6fd0>,
#  'onions': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c5d0>,
#  'organic': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c3d0>,
#  'greek': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cdd0>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c490>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cf10>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c190>,
#  'clusters': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cc50>,
#  'bar': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c0d0>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c310>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cb10>,
#  '': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c210>,
#  'chs': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cc90>,
#  'kroger': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c2d0>,
#  'diced': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cb50>,
#  'kro': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cfd0>,
#  'parmesan': <gensim.models.keyedvectors.Vocab at 0x7f3cd366ccd0>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c110>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cad0>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c350>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x7f3cd366ca90>,
#  'radishes': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c810>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c690>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c450>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cd10>,
#  'peppers': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cf50>,
#  'sto': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c250>,
#  'taylor': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c1d0>,
#  'farms': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c790>,
#  'avocado': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c650>,
#  'ranch': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c9d0>,
#  'chopped': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cb90>,
#  'salad': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c990>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x7f3cd366ced0>,
#  'tyfr': <gensim.models.keyedvectors.Vocab at 0x7f3cd366ce90>,
#  'roasted': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c890>,
#  'crv': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c8d0>,
#  'deposit': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c950>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c290>,
#  'redem': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c050>,
#  'val': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cbd0>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c710>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c090>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7f3cd366ca50>,
#  'italian': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c510>,
#  'plant-based': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cc10>,
#  'sausage': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c750>,
#  'bynd': <gensim.models.keyedvectors.Vocab at 0x7f3cd366ca10>,
#  'ssg': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c7d0>,
#  'ht': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c550>,
#  'itln': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c4d0>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c610>,
#  'bbq': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c850>,
#  'almonds': <gensim.models.keyedvectors.Vocab at 0x7f3cd366c150>,
#  'bldm': <gensim.models.keyedvectors.Vocab at 0x7f3cd366cf90>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61b50>,
#  'fancy': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61410>,
#  'feast': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61f90>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61c90>,
#  'pate': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61b90>,
#  'chicken': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61f50>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d619d0>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61350>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61950>,
#  'ffst': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61d10>,
#  'shrimp': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61d50>,
#  'tender': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61890>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61ed0>,
#  'liver': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61510>,
#  'flavor': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61250>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61090>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61a10>,
#  'seafood': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61290>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61490>,
#  'grilled': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d610d0>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61190>,
#  'gravy': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61fd0>,
#  'salmon': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61850>,
#  'sliced': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61610>,
#  'hearts': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61a50>,
#  'hatch': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61310>,
#  'chiles': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61ad0>,
#  'oz': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61650>,
#  'ppr': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61e50>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61e90>,
#  'lightly': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61b10>,
#  'salted': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61810>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d612d0>,
#  'soap': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61c10>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61050>,
#  'smartwater': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61690>,
#  'vapor': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61450>,
#  'distilled': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61750>,
#  'glac': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61bd0>,
#  'smrtwtr': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61a90>,
#  'oscar': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61390>,
#  'mayer': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61f10>,
#  'naturally': <gensim.models.keyedvectors.Vocab at 0x7f3cd3d61590>,
#  'hardwood': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099890>,
#  'smoked': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099090>,
#  'bacon': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099150>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099cd0>,
#  'spinach': <gensim.models.keyedvectors.Vocab at 0x7f3cd40994d0>,
#  'romaine': <gensim.models.keyedvectors.Vocab at 0x7f3cd40998d0>,
#  'orgnc': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099650>,
#  'nut': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099190>,
#  'arrowhead': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099f10>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099550>,
#  'crystal': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099250>,
#  'geyser': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099850>,
#  'alpine': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099910>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099810>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099b90>,
#  'cgys': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099fd0>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099510>,
#  'avocados': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099610>,
#  'tuna': <gensim.models.keyedvectors.Vocab at 0x7f3cd40997d0>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099a50>,
#  'lovers': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099690>,
#  'turkey': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099210>,
#  'medleys': <gensim.models.keyedvectors.Vocab at 0x7f3cd40999d0>,
#  'florentine': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099d50>,
#  'lmtd': <gensim.models.keyedvectors.Vocab at 0x7f3cd40993d0>,
#  'qty': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099ad0>,
#  'alkaline': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099b50>,
#  'fiji': <gensim.models.keyedvectors.Vocab at 0x7f3cd40990d0>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099450>,
#  'abound': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099e50>,
#  'litter': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099950>,
#  'coconut': <gensim.models.keyedvectors.Vocab at 0x7f3cd4099310>,
#  'hass': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31a50>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31b50>,
#  'str': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31c10>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31d90>,
#  'burger': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31090>,
#  'patties': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31f90>,
#  'boars': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31d10>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31e90>,
#  'monterey': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31d50>,
#  'jack': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b311d0>,
#  'jalapeno': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31310>,
#  'brhd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31c50>,
#  'broccoli': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31190>,
#  'cauliflower': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b310d0>,
#  'celery': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31150>,
#  'sauce': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31cd0>,
#  'cucumber': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31bd0>,
#  'english': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31fd0>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b31a90>,
#  'bags': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b319d0>,
#  'mozzarella': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c450>,
#  'string': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cad0>,
#  'galbani': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cbd0>,
#  'glbni': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c1d0>,
#  'bf': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c810>,
#  'leaf': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c750>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5ca50>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cd90>,
#  'les': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cd10>,
#  'fs': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5ce50>,
#  'kalamata': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c890>,
#  'olives': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c990>,
#  'broth': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c4d0>,
#  'pods': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cc90>,
#  'unsweetened': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c510>,
#  'dairy-free': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cb90>,
#  'creamer': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c150>,
#  'nutpods': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c950>,
#  'jumbo': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cd50>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cdd0>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cc10>,
#  'org': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c050>,
#  'cabbage': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c090>,
#  'parsley': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cf50>,
#  'squash': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cb10>,
#  'tomatoes': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5ca10>,
#  'tomato': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c490>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c650>,
#  'private': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c590>,
#  'selection': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5ce10>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c610>,
#  'prsl': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cf10>,
#  'purina': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cc50>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c250>,
#  'savory': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5ce90>,
#  'minced': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5ced0>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c5d0>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c0d0>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cfd0>,
#  'roast': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c910>,
#  'pecan': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c310>,
#  'halves': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c2d0>,
#  'raw': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c410>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c190>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5ca90>,
#  'cashews': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5c8d0>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x7f3cd3b5cf90>,
#  'lean': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732e50>,
#  'chk': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732450>,
#  'kitchen': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732dd0>,
#  'salame': <gensim.models.keyedvectors.Vocab at 0x7f3cd37328d0>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732850>,
#  'pacf': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732310>,
#  'deli': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732d50>,
#  'brat': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732b50>,
#  'links': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732f10>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732810>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732510>,
#  'applegate': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732390>,
#  'uncured': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732650>,
#  'apgt': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732e10>,
#  'frm': <gensim.models.keyedvectors.Vocab at 0x7f3cd37325d0>,
#  'cheddar': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732710>,
#  'cau': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732e90>,
#  'matzo': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732a90>,
#  'soup': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732090>,
#  'meal': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732490>,
#  'buffalo': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732950>,
#  'lentil': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732c10>,
#  'kerrygold': <gensim.models.keyedvectors.Vocab at 0x7f3cd37329d0>,
#  'irish': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732110>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732d10>,
#  'cuc': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732990>,
#  'rpc': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732050>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f3cd37321d0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732250>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732c50>,
#  'sour': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732150>,
#  'tissue': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732350>,
#  'fully': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732ad0>,
#  'cooked': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732ed0>,
#  'vanilla': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732750>,
#  'chunky': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732cd0>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732690>,
#  'sargento': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732290>,
#  'slices': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732b90>,
#  'shredded': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732a50>,
#  'starbucks': <gensim.models.keyedvectors.Vocab at 0x7f3cd37323d0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732410>,
#  'krgd': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732210>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732f90>,
#  'ckn': <gensim.models.keyedvectors.Vocab at 0x7f3cd37322d0>,
#  'strng': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732bd0>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x7f3cd3732c90>}

# %%
model.wv.similar_by_word('cheese')
# Out:
# 2020-04-28 21:59:49,665 : INFO : precomputing L2-norms of word weight vectors
# [('feast', 0.7685936093330383),
#  ('french', 0.7592940330505371),
#  ('smoked', 0.7346859574317932),
#  ('beyond', 0.7333604097366333),
#  ('grade', 0.7325740456581116),
#  ('ground', 0.7305741310119629),
#  ('wet', 0.7256548404693604),
#  ('', 0.7255364656448364),
#  ('hot', 0.7243200540542603),
#  ('-', 0.7217936515808105)]

# %%
model.wv.similar_by_word('kro')
# Out:
# [('pacf', 0.5085748434066772),
#  ('with', 0.4650784730911255),
#  ('chopped', 0.4405178427696228),
#  ('natural', 0.4364372193813324),
#  ('lmtd', 0.43595147132873535),
#  ('food', 0.4341128170490265),
#  ('ranch', 0.43262341618537903),
#  ('a', 0.42758044600486755),
#  ('gravy', 0.42737022042274475),
#  ('dairy-free', 0.42728391289711)]

# %%
model.wv.similar_by_word('kroger')
# Out:
# [('feast', 0.5828536152839661),
#  ('hot', 0.5772860646247864),
#  ('french', 0.5749461650848389),
#  ('original', 0.5731462836265564),
#  ('fancy', 0.5688536167144775),
#  ('', 0.5653416514396667),
#  ('dairy-free', 0.5573346614837646),
#  ('organic', 0.5519124269485474),
#  ('creamer', 0.5517327189445496),
#  ('meat', 0.5507047772407532)]

# %%
model.wv.similar_by_word('jalapenos')
# Out:
# [('egglands', 0.39589881896972656),
#  ('roasted', 0.3936736285686493),
#  ('ground', 0.36728888750076294),
#  ('avocado', 0.364783376455307),
#  ('uncured', 0.3543057143688202),
#  ('free', 0.3492000102996826),
#  ('gourmet', 0.33909812569618225),
#  ('naturally', 0.3387349843978882),
#  ('a', 0.3379022777080536),
#  ('bynd', 0.3332291543483734)]

# %%
model2 = Word2Vec(ReceiptIter(), size=10)
# Out:
# 2020-04-28 22:15:56,876 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-04-28 22:15:56,877 : INFO : collecting all words and their counts
# 2020-04-28 22:15:56,878 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-28 22:15:56,891 : INFO : collected 1024 word types from a corpus of 6082 raw words and 1422 sentences
# 2020-04-28 22:15:56,892 : INFO : Loading a fresh vocabulary
# 2020-04-28 22:15:56,893 : INFO : effective_min_count=5 retains 262 unique words (25% of original 1024, drops 762)
# 2020-04-28 22:15:56,893 : INFO : effective_min_count=5 leaves 4724 word corpus (77% of original 6082, drops 1358)
# 2020-04-28 22:15:56,894 : INFO : deleting the raw counts dictionary of 1024 items
# 2020-04-28 22:15:56,895 : INFO : sample=0.001 downsamples 107 most-common words
# 2020-04-28 22:15:56,895 : INFO : downsampling leaves estimated 2937 word corpus (62.2% of prior 4724)
# 2020-04-28 22:15:56,896 : INFO : estimated required memory for 262 words and 10 dimensions: 151960 bytes
# 2020-04-28 22:15:56,896 : INFO : resetting layer weights
# 2020-04-28 22:15:56,942 : INFO : training model with 3 workers on 262 vocabulary and 10 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-04-28 22:15:56,957 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 22:15:56,958 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 22:15:56,960 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 22:15:56,960 : INFO : EPOCH - 1 : training on 6082 raw words (2881 effective words) took 0.0s, 166762 effective words/s
# 2020-04-28 22:15:56,975 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 22:15:56,976 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 22:15:56,979 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 22:15:56,979 : INFO : EPOCH - 2 : training on 6082 raw words (2924 effective words) took 0.0s, 166733 effective words/s
# 2020-04-28 22:15:56,994 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 22:15:56,995 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 22:15:56,998 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 22:15:56,999 : INFO : EPOCH - 3 : training on 6082 raw words (2927 effective words) took 0.0s, 159319 effective words/s
# 2020-04-28 22:15:57,013 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 22:15:57,014 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 22:15:57,017 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 22:15:57,017 : INFO : EPOCH - 4 : training on 6082 raw words (2899 effective words) took 0.0s, 169439 effective words/s
# 2020-04-28 22:15:57,032 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-28 22:15:57,033 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-28 22:15:57,035 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-28 22:15:57,036 : INFO : EPOCH - 5 : training on 6082 raw words (2930 effective words) took 0.0s, 169692 effective words/s
# 2020-04-28 22:15:57,036 : INFO : training on a 30410 raw words (14561 effective words) took 0.1s, 155348 effective words/s
# 2020-04-28 22:15:57,036 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model2.wv.similar_by_word('eggs')
# Out:
# 2020-04-28 22:16:36,466 : INFO : precomputing L2-norms of word weight vectors
# [('french', 0.8073101043701172),
#  ('qty', 0.7961218357086182),
#  ('naturally', 0.7954999208450317),
#  ('flavor', 0.7710254192352295),
#  ('turkey', 0.7475664615631104),
#  ('tender', 0.7101244926452637),
#  ('with', 0.6879206895828247),
#  ('jalapenos', 0.6788337230682373),
#  ('food', 0.6744784116744995),
#  ('pure', 0.6739354729652405)]

# %%
model.wv.similar_by_word('eggs')
# Out:
# [('turkey', 0.6665092706680298),
#  ('feast', 0.6415066719055176),
#  ('', 0.633222758769989),
#  ('fancy', 0.6275984644889832),
#  ('a', 0.6264246106147766),
#  ('bacon', 0.6144722700119019),
#  ('large', 0.6093783378601074),
#  ('french', 0.6074662208557129),
#  ('qty', 0.6065540313720703),
#  ('grade', 0.6045123338699341)]
